# %% [markdown]
# <a href="https://colab.research.google.com/github/inesfrsantos/MachineLearning/blob/main/Final_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Analysis and Preprocessing
# ## Load needed packages and Data

# %%
import pandas as pd
import os
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
import hashlib
import time
import psutil
import os
import random
import shutil
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from tqdm import tqdm 
from sklearn.metrics import classification_report
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler
from sklearn.metrics import confusion_matrix

# %%
# Data is stored in a GitHub Repository
# !git clone https://github.com/inesfrsantos/MachineLearning.git
# Out:
# fatal: destination path 'MachineLearning' already exists and is not an empty directory.

# %%
# !ls
# Out:
# MachineLearning  sample_data

# %%
path = "/content/MachineLearning/Dataset/ArASL_Database_54K_Final"

# %%
# create empty lists to store image file paths, images, and labels
img_path = []
images = []
labels = []

# loop through each folder in the path
for folder_name in os.listdir(path):
    # create the full path to the folder
    folder_path = os.path.join(path, folder_name)
    # skip any non-directory files
    if not os.path.isdir(folder_path):
        continue
    # loop through each file in the folder
    for file_name in os.listdir(folder_path):
        # check if the file is a jpg, png, JPG, or PNG file
        if file_name.endswith(".jpg") or file_name.endswith(".png") or file_name.endswith(".JPG") or file_name.endswith(".PNG"):
            # create the full path to the image file
            image_path = os.path.join(folder_path, file_name)
            # check if the file is a regular file
            if os.path.isfile(image_path):
                # open the image file and convert it to grayscale
                image = Image.open(image_path).convert('L')
                # append the image file path, image, and label to their respective lists
                images.append(image)
                labels.append(folder_name)
                img_path.append(image_path)

# create a pandas dataframe with the image file paths, images, and labels as columns
df = pd.DataFrame({'img_path': img_path, 'image': images, 'label': labels})

# %% [markdown]
# ## Exploratory Analysis

# %%
#get the total number of pictures in the dataset
num_pics = len(df)
print("Number of pictures in the dataset:\n")
print(num_pics, "\n")

#get the total number of pictures per category and the corresponding percentage
label_counts = df['label'].value_counts()
print("Number and Percentage of pictures per Label:\n")
for label, count in label_counts.items():
    percentage = count/num_pics * 100
    print(f"{label}: {count} ({percentage:.2f}%)")
# Out:
# Number of pictures in the dataset:
#
# 38645
#
# Number and Percentage of pictures per Label:
#
# ain: 1771 (4.58%)
# ghain: 1564 (4.05%)
# fa: 1464 (3.79%)
# ta: 1454 (3.76%)
# nun: 1342 (3.47%)
# laam: 1326 (3.43%)
# ra: 1321 (3.42%)
# bb: 1311 (3.39%)
# dal: 1308 (3.38%)
# dha: 1297 (3.36%)
# gaaf: 1296 (3.35%)
# toot: 1281 (3.31%)
# meem: 1277 (3.30%)
# ha: 1274 (3.30%)
# saad: 1270 (3.29%)
# khaa: 1245 (3.22%)
# ya: 1228 (3.18%)
# haa: 1191 (3.08%)
# la: 1178 (3.05%)
# thal: 1177 (3.05%)
# taa: 1164 (3.01%)
# dhad: 1137 (2.94%)
# jeem: 1108 (2.87%)
# zay: 1108 (2.87%)
# thaa: 1107 (2.86%)
# yaa: 1063 (2.75%)
# kaaf: 1029 (2.66%)
# aleff: 1018 (2.63%)
# sheen: 898 (2.32%)
# al: 896 (2.32%)
# waw: 785 (2.03%)
# seen: 757 (1.96%)

# %%
# plot the count of images per Label
# Get unique labels from the dataframe
Label = df['label'].unique()

# Set the size of the plot
plt.figure(figsize=(16,4))

# Create a bar chart of label counts
plt.bar(range(len(label_counts)), label_counts, alpha = .7)

# Set x-axis tick marks and labels to the unique labels
plt.xticks(range(len(label_counts)), Label, rotation = 45)

# Set x and y axis labels
plt.xlabel("Label")
plt.ylabel("Amount")

# Display the plot
plt.show()

# %%
# Plot Examples of all signs with theri best quality
# Get one image for each label
label_to_image = {}
for label in df['label'].unique():
    label_df = df[df['label'] == label]
    variances = [np.var(np.array(image)) for image in label_df['image']]
    max_idx = np.argmax(variances)
    label_to_image[label] = label_df.iloc[max_idx]['image']

# Create a figure with subplots
fig, axs = plt.subplots(nrows=int(np.ceil(len(label_to_image) / 8)), ncols=8, figsize=(32, 12))

# Loop over each label and plot the corresponding image
for i, (label, image) in enumerate(label_to_image.items()):
    row = i // 8
    col = i % 8
    axs[row, col].imshow(image, cmap='gray')
    axs[row, col].set_title(label, fontsize=20)
    axs[row, col].axis('off')

# Adjust spacing and display the plot
fig.tight_layout()
plt.show()

# %%
# plot the square root size vs aspect ratio to see the distribution of sizes
# first calculate the square root size and the aspect ratio
square_root_size = []
aspect_ratio = []
for image in df['image']:
  #size of the images in pixels
  width, height = image.size
  
  #calculate the square root size
  sqrt_size = (width * height) ** 0.5
  square_root_size.append(sqrt_size)

  #cxalculate the aspect_ration
  aspt_rt = width/height
  aspect_ratio.append(aspt_rt)

# plot the data
fig, ax = plt.subplots()
ax.scatter(aspect_ratio, square_root_size)

# add labels and a title
ax.set_xlabel("aspect ratio")
ax.set_ylabel("square root size")
ax.set_title("square root size vs. aspect ratio")

# show the plot
plt.show()

# %%
df['aspect_ratio'] = aspect_ratio
df['square_root_size'] = square_root_size

# %%
# Calculate the number of images with different aspect ratios than 1:1.
num_dif_ratio = len(np.where(df['aspect_ratio'] != 1)[0])
print(f"Number of different ratio: {num_dif_ratio}")
# Out:
# Number of different ratio: 10

# %%
#reduce the dataframe to the rows that have a different aspect ratio than 1
df_asp = df.loc[df['aspect_ratio'] != 1]

# Define the number of columns in the figure
num_cols = 5

# Calculate the number of rows needed
num_rows = len(df_asp) // num_cols

# Create a new figure
fig, axes = plt.subplots(num_rows, num_cols, figsize=(32, 12))

# Flatten the axes array for ease of iteration
axes = axes.flatten()

# Loop through each image in the DataFrame and display it
for i, (_, row) in enumerate(df_asp.iterrows()):
    img = row['image']
    ax = axes[i]
    ax.imshow(img, cmap='gray')
    ax.set_title(row['label'])
    ax.axis('off')
    
# Remove any unused axes
for i in range(len(df), num_rows * num_cols):
    axes[i].axis('off')
    
plt.tight_layout()
plt.show()

# %%
# Find rows where the image size is not (64,64)
non_6464_rows = df[df['image'].apply(lambda x: x.size) != (64,64)]

#get the total number of pictures that are not size (64,64)
num_pics_64 = len(non_6464_rows)
num_pics = len(df)
Perc_of_whole = num_pics_64/num_pics * 100
print("Number of pictures with different size:\n")
print(num_pics_64)
print("That is", f"{Perc_of_whole:.2f}%", "of the whole dataset \n")

#split the information per category
label_counts_64 = non_6464_rows['label'].value_counts()
label_counts = df['label'].value_counts()
print("Number and Percentage of different sized pictures per Label:")
print("(The Percentage refers to the number of all pictures of that label):\n")
for label, count in label_counts_64.items():
    percentage = count/label_counts[label] * 100
    print(f"{label}: {count} ({percentage:.2f}%)")
# Out:
# Number of pictures with different size:
#
# 33
# That is 0.09% of the whole dataset
#
# Number and Percentage of different sized pictures per Label:
# (The Percentage refers to the number of all pictures of that label):
#
# meem: 13 (1.02%)
# kaaf: 10 (0.97%)
# haa: 10 (0.84%)

# %%
# Color Channel Analysis
def get_channel_means(image):
    return np.mean(np.array(image))
# Initialize a list to store the mean pixel intensity of each color channel
channel_means = []

# Loop through the images in the dataset and calculate the channel means
for i in range(len(df)):
    image = df['image'][i]
    channel_means.append(get_channel_means(image))

# Convert the channel means to a numpy array and calculate the mean and standard deviation for the channel
channel_means = np.array(channel_means)
mean_intensity = np.mean(channel_means)
std_intensity = np.std(channel_means)

# Print the mean and standard deviation for the channel
print("Mean pixel intensity: {:.2f}".format(mean_intensity))
print("Standard deviation of pixel intensity: {:.2f}".format(std_intensity))
# Out:
# Mean pixel intensity: 181.31
# Standard deviation of pixel intensity: 28.93

# %% [markdown]
# ## Preprocessing

# %%
filtered_images = []

# %%
# Check for Duplicates

def get_hash(img_path):
    """
    Calculates the MD5 checksum of the input image.

    Args:
        img_path (str): The file path of the input image.

    Returns:
        str: The MD5 checksum of the image.
    """
    # Open the input image in binary mode
    with open(img_path, "rb") as f:
        # Initialize a new MD5 hash object
        img_hash = hashlib.md5()
        # Read the image data in chunks and update the hash object with each chunk
        while chunk := f.read(8192):
           img_hash.update(chunk)
    # Return the hexadecimal representation of the hash value
    return img_hash.hexdigest()

# %%
#Add a column to the DataFrame to store the hash values for each image in the dataset
df['hash'] = df['img_path'].apply(get_hash)

#Calculate the number of unique hash values in the dataset and identify duplicates based on the hash value
unique_values = df['hash'].nunique()
duplicates = df[df.duplicated(['hash'])]

#Print the number of duplicates found in the dataset
print("Duplicates in the Dataset based on the calculated hash value:")
print(len(duplicates), '\n')

#Print the total number of images in the dataset before dropping duplicates
print("Images in the Dataset before dropping Duplicates:")
print(len(df), '\n')

#Drop the duplicate images from the dataset based on the hash value and reset the index
df.drop_duplicates(subset=['hash'], inplace=True)
df = df.reset_index(drop=True)

#Print the total number of images in the dataset after dropping duplicates
print("Images in the Dataset after dropping Duplicates:")
print(len(df))

image_path = duplicates['img_path']
print(image_path)
for path in image_path:
  filtered_images.append(path)

print(len(filtered_images))
# Out:
# Duplicates in the Dataset based on the calculated hash value:
# 0
#
# Images in the Dataset before dropping Duplicates:
# 38645
#
# Images in the Dataset after dropping Duplicates:
# 38645
# Series([], Name: img_path, dtype: object)
# 0

# %%
# Create an empty list to store the anomaly scores for each image
anomaly_scores = []

# Loop through each image in the dataset
for i in range(len(df)):
    # Load the image
    image = df.loc[i, 'image']
    
    # Calculate the mean and standard deviation of the image
    mean = np.mean(image)
    std = np.std(image)
    
    # Calculate the anomaly score
    anomaly_score = np.abs((image - mean) / std).mean()
    anomaly_scores.append(anomaly_score)

# Add the anomaly scores as a new column to the dataframe
df['anomaly_score'] = anomaly_scores

# Print the dataframe sorted by anomaly score
print(df.sort_values(by='anomaly_score', ascending=False))
# Out:
#                                                 img_path  \
# 1160   /content/MachineLearning/Dataset/ArASL_Databas...
# 36996  /content/MachineLearning/Dataset/ArASL_Databas...
# 23404  /content/MachineLearning/Dataset/ArASL_Databas...
# 29705  /content/MachineLearning/Dataset/ArASL_Databas...
# 37205  /content/MachineLearning/Dataset/ArASL_Databas...
# ...                                                  ...
# 15969  /content/MachineLearning/Dataset/ArASL_Databas...
# 4105   /content/MachineLearning/Dataset/ArASL_Databas...
# 23522  /content/MachineLearning/Dataset/ArASL_Databas...
# 22639  /content/MachineLearning/Dataset/ArASL_Databas...
# 8021   /content/MachineLearning/Dataset/ArASL_Databas...
#
#                                                    image  label  aspect_ratio  \
# 1160   <PIL.Image.Image image mode=L size=64x64 at 0x...  ghain           1.0
# 36996  <PIL.Image.Image image mode=L size=64x64 at 0x...    dha           1.0
# 23404  <PIL.Image.Image image mode=L size=64x64 at 0x...    taa           1.0
# 29705  <PIL.Image.Image image mode=L size=64x64 at 0x...   laam           1.0
# 37205  <PIL.Image.Image image mode=L size=64x64 at 0x...    dha           1.0
# ...                                                  ...    ...           ...
# 15969  <PIL.Image.Image image mode=L size=64x64 at 0x...   meem           1.0
# 4105   <PIL.Image.Image image mode=L size=64x64 at 0x...    waw           1.0
# 23522  <PIL.Image.Image image mode=L size=64x64 at 0x...    taa           1.0
# 22639  <PIL.Image.Image image mode=L size=64x64 at 0x...    taa           1.0
# 8021   <PIL.Image.Image image mode=L size=64x64 at 0x...    dal           1.0
#
#        square_root_size                              hash  anomaly_score
# 1160               64.0  a8371eb309b5d6e213306f5e954fdc30       0.849997
# 36996              64.0  f467ebf7b53124fc8d81377abc8fbc9d       0.849997
# 23404              64.0  a3d80b8bd16bc8feacd035fa486b59bd       0.849993
# 29705              64.0  e60d9b831fe0496530e86f633b002524       0.849991
# 37205              64.0  899b72df71b297e9ca5233cca8599e97       0.849988
# ...                 ...                               ...            ...
# 15969              64.0  5c66354974afd5cb2daedc0a4ed2d73f       0.481937
# 4105               64.0  d16b91b1873051b3321f8da7bfe08ba4       0.475243
# 23522              64.0  b044cf9920e191d40f2a8eab4e763647       0.468129
# 22639              64.0  d182aaf6cddbda8a406a7534e66e2553       0.443558
# 8021               64.0  c65ff0291608e262755b32f0b82ddcf4       0.422069
#
# [38645 rows x 7 columns]

# %%
#Filter out images with anomaly scores above 0.85
anomal_img = df.loc[df['anomaly_score'] >= 0.85]
df_filtered = df.loc[df['anomaly_score'] < 0.85]

#Reset the index to start from 0
df_filtered = df_filtered.reset_index(drop=True)

#Print the number of images in the filtered dataset
print('Number of pictures in the dataset after filtering:')
print(len(df_filtered))

image_path = anomal_img['img_path']
for path in image_path:
  filtered_images.append(path)

print(len(filtered_images))
# Out:
# Number of pictures in the dataset after filtering:
# 38645
# 0

# %%
# filter the images from the train and test directories
for image_path in filtered_images:
  os.remove(image_path)

# %%
#!zip -r /content/MachineLearning/Dataset/filtered_Dataset.zip /content/MachineLearning/Dataset/ArASL_Database_54K_Final

# %%
# define the directory containing the images
original_dir = '/content/MachineLearning/Dataset/SignLanguage_filtered'

# define the directories for the training, validation, and test sets
train_dir = '/content/MachineLearning/Dataset/train_set'
val_dir = '/content/MachineLearning/Dataset/valid_set'
test_dir = '/content/MachineLearning/Dataset/test_set'

# create the directories for the training, validation, and test sets
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# define the size of the validation and test sets
val_size = 0.2
test_size = 0.2

# loop through the subdirectories in the original directory and copy the files to the train, validation, or test directories
for sub_dir in os.listdir(original_dir):
    sub_dir_path = os.path.join(original_dir, sub_dir)
    if not os.path.isdir(sub_dir_path):
        continue
    print(f'Processing {sub_dir_path}...')
    files = os.listdir(sub_dir_path)
    random.shuffle(files)
    num_files = len(files)
    num_val = int(val_size * num_files)
    num_test = int(test_size * num_files)
    num_train = num_files - num_val - num_test
    train_files = files[:num_train]
    val_files = files[num_train:num_train+num_val]
    test_files = files[num_train+num_val:]
    for filename in train_files:
        src = os.path.join(sub_dir_path, filename)
        dst = os.path.join(train_dir, sub_dir, filename)
        os.makedirs(os.path.dirname(dst), exist_ok=True)
        shutil.copy(src, dst)
    for filename in val_files:
        src = os.path.join(sub_dir_path, filename)
        dst = os.path.join(val_dir, sub_dir, filename)
        os.makedirs(os.path.dirname(dst), exist_ok=True)
        shutil.copy(src, dst)
    for filename in test_files:
        src = os.path.join(sub_dir_path, filename)
        dst = os.path.join(test_dir, sub_dir, filename)
        os.makedirs(os.path.dirname(dst), exist_ok=True)
        shutil.copy(src, dst)
# Out:
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/ghain...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/la...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/saad...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/waw...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/bb...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/seen...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/jeem...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/dal...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/gaaf...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/ya...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/thal...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/ta...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/fa...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/meem...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/dhad...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/kaaf...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/sheen...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/ha...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/al...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/taa...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/toot...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/yaa...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/nun...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/ra...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/laam...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/aleff...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/ain...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/zay...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/haa...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/thaa...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/dha...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/khaa...

# %% [markdown]
# ## Data Augmentation on the training set

# %%
path = "/content/MachineLearning/Dataset/train_set"

# loop through the folders and augment images
for folder in os.listdir(path):
    print(folder)
    if folder == '.DS_Store':
        continue
    else:
        folder_path = os.path.join(path, folder)
        print(folder_path)
        for file in os.listdir(folder_path):
            if file == '.DS_Store':
                continue
            else:
                file_path = os.path.join(folder_path, file)
                print(file_path)
                image = tf.keras.preprocessing.image.load_img(file_path)
                image = tf.keras.preprocessing.image.img_to_array(image)
                image = np.expand_dims(image, axis=0)

                # Randomly select an augmentation operation
                operations = {
                    'rotation': random.choice([True, False]),
                    'width_shift': random.choice([True, False]),
                    'height_shift': random.choice([True, False]),
                    'shear': random.choice([True, False]),
                    'zoom': random.choice([True, False]),
                    'horizontal_flip': random.choice([True, False])
                }

                # Apply selected augmentation operation
                if operations['rotation']:
                    rotation_range = random.randint(1, 30)
                else:
                    rotation_range = 0

                if operations['width_shift']:
                    width_shift_range = random.uniform(0.1, 0.2)
                else:
                    width_shift_range = 0.0

                if operations['height_shift']:
                    height_shift_range = random.uniform(0.1, 0.2)
                else:
                    height_shift_range = 0.0

                if operations['shear']:
                    shear_range = random.uniform(0.1, 0.2)
                else:
                    shear_range = 0.0

                if operations['zoom']:
                    zoom_range = random.uniform(0.1, 0.2)
                else:
                    zoom_range = 0.0

                if operations['horizontal_flip']:
                    horizontal_flip = True
                else:
                    horizontal_flip = False

                image_generator = tf.keras.preprocessing.image.ImageDataGenerator(
                    rotation_range=rotation_range,
                    width_shift_range=width_shift_range,
                    height_shift_range=height_shift_range,
                    shear_range=shear_range,
                    zoom_range=zoom_range,
                    horizontal_flip=horizontal_flip,
                    fill_mode='nearest'
                )

                augmented_image_iterator = image_generator.flow(image, batch_size=1)
                augmented_image = next(augmented_image_iterator)
                augmented_image = augmented_image[0].astype('uint8')
                augmented_image = tf.keras.preprocessing.image.array_to_img(augmented_image)
                filename, extension = os.path.splitext(file)
                new_filename = filename + '_aug' + extension
                new_file_path = os.path.join(folder_path, new_filename)
                augmented_image.save(new_file_path)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1592)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1273)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1151).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (646)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1141).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (988).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (815).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1140)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (767).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (682).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1290).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1152).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1532)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (324).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1146)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1604).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (782)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1561)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (914)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (29).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (17)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1086)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (84).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1042).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1338).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1519).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (588)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (76)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1381).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1613)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (731)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1617)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1617).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (811).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (715).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (881).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (869).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (952)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (663).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1352)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1273).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (323)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1096)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1510).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (13).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (36).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (941).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1567).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (653).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1523).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1311).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (831).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1401)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (926).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (940).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (802).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (877).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1125).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1491).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1539).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (141)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1474)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1526).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (748).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (957).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (829).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1505)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (642).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1616)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (738).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (116).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1065).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (319).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1277)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1100).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1508)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (8).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1494).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (735).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (919)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1753).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (705)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (119)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1091)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (714)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1304)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (970)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1082).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1497).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1474).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1615).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (766).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (18)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (840).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1641).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1329).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (865)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1569).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1461).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (15).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1139).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (792).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (86).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (897).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1287).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1533)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (709).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (691).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (950)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (78)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (674).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1157)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (143).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (678)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1112)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1508).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1270)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (909)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (786)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (722).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (769)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (893)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (22).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (790)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1571)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1644)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (144).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (832)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1496).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (43)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (671)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1586)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1505).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (806)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (762).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1453).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (104).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1281)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (722)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1530)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1118)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (318).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1546).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1052).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1495).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (675).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1721).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (935).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1532).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1403).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1081).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1603)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1045).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1041).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1531)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (648)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1292)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (991)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1465).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (50).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1491)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (735)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1517)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1550).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1117)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1349).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1377).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (103)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (152).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (819).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (54)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1459).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (809)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1045)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (920)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (830).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (50)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (972).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (95).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (960).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1295)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1564)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1578)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (919).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (669)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1600).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1005)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (859)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (990).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1502)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1334)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (773).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (868).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1758).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1386)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (754).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (311)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (831)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (783)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1639).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1262).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (904).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1056).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (72).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1761)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (676)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (922)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (145)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (729)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (313).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1634)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1644).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (644).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1422).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (99).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1066)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (57).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (885).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1468).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (991).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (30)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (907).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1075).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (856).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (889)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (810)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (317).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (797).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (996)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1070)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1527).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1564).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (843).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (974)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1530).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (57)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1319).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1277).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (740).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (854).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (882)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1010).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1062)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (657)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (123)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (814)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1051)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (161)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1008).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (843)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1576)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1376)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1513).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (46).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (898).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (727).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (662)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1330).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1753)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1292).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1369).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1390).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (887)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (935)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (91)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (318)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1560)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (307)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (834).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (724)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (772)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1260)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (975)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1286).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (44)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1486).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1550)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1486)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1098).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1348)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1154).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1557).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (111).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1479).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (962).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (666)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (344).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1291).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1638).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1049).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1437).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (34)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (266).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (121)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1761).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1165)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (267)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1388).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1719).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (889).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1006)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1426).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1264)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1389).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (78).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (778).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (654).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (773)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1092).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (187)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (913)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (870).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1371)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (898)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1634).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (680).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (264)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1346).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1406)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1009).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (35)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1424)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (341).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1515)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1340)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (853).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (544)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (884).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (836).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1412).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (711)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1072)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (810).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1439).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1755).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (932)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1132)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1362).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1042)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1360)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1104)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1620).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (309).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (942)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (153)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (745).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (993).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1137).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (652).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1520)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (730)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1511).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (947).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1073)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (114).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1357).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (696).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (111)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (892)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1367)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1445).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (18).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (844).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (678).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1586).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (92)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (816)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (842).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (142).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1535)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (77).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (981).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1111).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (724).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1579).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (877)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1461)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (906)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (795).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1162).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (947)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1672)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (823)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (650).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (320)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1306)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1679).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1322).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1278)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1116).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (147)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (992).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (880).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (727)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1641)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1755)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (60)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (962)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1300)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1134).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1409)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1756)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (793).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (883)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (103).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (824).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1608).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1534)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (692)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1556)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1548)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (781)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1128)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (701)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (876).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1328)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (838)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (131)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (308)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1170).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1124)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (21)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (990)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (106).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (746).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1361)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1680).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (48)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (646).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1143).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1568).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (753).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (710).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1053)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (779)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (826).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1407)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (792)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1524)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (940)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (844)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1576).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1294).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (924)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1157).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1280).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (867)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1299)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1614)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (823).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (778)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1585).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1167).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (670)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1518).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1101)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1470)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (70)_aug.JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1593)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (708).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (112).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (133).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1007).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (822)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (930).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1293).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (48).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (828).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (850).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1272)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (944).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (963).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1160)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (923)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1110).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (807)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1452)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (683).JPG
# /content/MachineLearning/Dataset/train_set/thaa/THAA (768).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (714).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1513)_aug.jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (1368).jpg
# /content/MachineLearning/Dataset/train_set/thaa/THAA (32)_aug.JPG
# dha
# /content/MachineLearning/Dataset/train_set/dha
# /content/MachineLearning/Dataset/train_set/dha/DHA (23).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (346).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (1110)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (977)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (958).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1680)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (9)_aug.JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (1143)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1078)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (584).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (953)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (404).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1377).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1721)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1463)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1712).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (427).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1660)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1300)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1709).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (445).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1277).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (239).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (163).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (359)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (37).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (1249)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1033).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (309)_aug.JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (490).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (498).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1035)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (13)_aug.JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (1295)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1329)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (546).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (598).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1277)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1531).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1646)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1291).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1610)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (460).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1467).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1269).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1083).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1049)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1596)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (385).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (288)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1537)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1553).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1119).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1281)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1544)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1280)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1228)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (457)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1264).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1040)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (121).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (563)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (306)_aug.JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (1567)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (84).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (681)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (646)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1290).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (332).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (1462)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1021).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (331).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (1428).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (960).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1081)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (88)_aug.JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (1011).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1719).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (505).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (964).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1367).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1434).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1588)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (489)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1088).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (48).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (1661)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (553).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1633)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1359).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1588).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1490)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1572).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (480).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (188).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (286).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1698)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (155)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1488).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (491).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (565).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (418).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1137).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1638)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1325).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1422).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1465)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (673).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (447)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (554)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1718).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1688).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (36).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (384)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (198)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1597).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (516).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1321).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (660)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (494)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1601)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1548).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1483).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (561).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (16).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (370).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1518).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (138)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (67)_aug.JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (1259).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1427)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (466).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (437).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1123).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (434).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1558).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1469).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (588).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1685)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1623).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (53).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (986)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (414).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1644).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1056).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1643)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (130).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (369)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1260).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (540).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1517).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (325).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (438).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (314)_aug.JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (569).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1328)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1586)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (295).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (578)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (670).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (687)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (473).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1716)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (348).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (1573).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (551)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1489).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1653)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1364).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (45)_aug.JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (151).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1041).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1602)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1720).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (929).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1282).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (923)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (45).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (350)_aug.JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (1703)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1458)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1093).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (191).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1252)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (326)_aug.JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (1448)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1029).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (67).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (987).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (624)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (428).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (999)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (924).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (503)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1346).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (349).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (479)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1347)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1372)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1493).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (929)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1577)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (943)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (184)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1645)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1143).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (574).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (399).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1378).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1630).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (387).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (422)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (2).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (1478)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1224).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (134).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1622).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (991)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (104).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (321)_aug.JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (448).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (457).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (90).JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (70)_aug.JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (378).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1302).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1626)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1604).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (440).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1702)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1064).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1010).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1134)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1576)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1682)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1715)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (525)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (57)_aug.JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (676).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (470).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1338).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (541)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1048)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1230)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (238).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1671)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (363).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1510).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1713)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1583).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (185)_aug.jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (417).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1312).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (84)_aug.JPG
# /content/MachineLearning/Dataset/train_set/dha/DHA (585).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (1100).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (547).jpg
# /content/MachineLearning/Dataset/train_set/dha/DHA (547)_aug.jpg
# ...
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1441).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (600).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1175)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1176)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1524)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1585).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (329)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1061).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (54)_aug.JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1189).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (555).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1513).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (934)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (435).JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (512).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (971).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1385).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1412).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1275).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1342)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (870)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (137).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1138)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1029).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (656)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1598).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1596)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1116).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (648).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (544).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1150).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (459)_aug.JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (957).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1603).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (996).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1323).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1448).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1113).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1341).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1423)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (464).JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (326).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (928)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (478).JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (581).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (601).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (557)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1417)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1191)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (131)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1600)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (505)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1393).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1435)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1444)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1504)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (101).JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (156)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (633).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1316)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (913)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (484).JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (457).JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1283).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1053)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (509).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (878)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (479).JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1481).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1069)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1235)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1392).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1347).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1496).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (193)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (899).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (85).JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1350)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (947).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1087)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (950)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (197)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (900)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1164).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (894)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1489).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1313)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (467)_aug.JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (345)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1510).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1326).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1587).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1583)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1404).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (155)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (894).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1240).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (557).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (467).JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (545)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (448)_aug.JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1120)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (126)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (532).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (497).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (550).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (146).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (655).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (943).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (996)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (588)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (640).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1427)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (156).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1)_aug.JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (147)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1448)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (92)_aug.JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1103)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1335).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (480).JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (483).JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (173).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (367).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1012)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1286)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1134).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (487)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1247)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (439)_aug.JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1127).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (217)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1319).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1241)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1177).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (631).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1425)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (46).JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1528).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (140)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (920).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (475)_aug.JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (486)_aug.JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (540).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (335).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1170)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (923)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1085).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (217).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (185)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (195)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (646)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1505).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (12)_aug.JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1577)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (875).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1105)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (620).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1398).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1280).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (592)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1167)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (838)_aug.JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (191)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (877).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (188).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (453).JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1447).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1349).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (922)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (556)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1478)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (657)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (570).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (956).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (484)_aug.JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1252).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (298)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1605).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (4)_aug.JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1279).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1297)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1235).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1288)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (648)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1380).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1173)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (517).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (983).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (542)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1374)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1497)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (638).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1331)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (212).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (567)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1243).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (682)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (896).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (637)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (651).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (990).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (165).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1310)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (553).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (852)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1561)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1072)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (218).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1485)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (366)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1288).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1437).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1231).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1117)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (152)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (54).JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (111).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1299).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1602).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (853)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (593)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (606)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (626).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1469)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (80).JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (537).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (892)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1055)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1352)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (451).JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (140).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (340)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (5)_aug.JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (325)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1062)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1450)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1568).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (27).JPG
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1090)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1132).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (229)_aug.jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (323).jpg
# /content/MachineLearning/Dataset/train_set/khaa/KHAA (1003)_aug.jpg

# %%
augmented_images = []

# loop through the folders and collect augmented images
for folder in os.listdir(path):
    if folder == '.DS_Store':
        continue
    else:
        folder_path = os.path.join(path, folder)
        for file in os.listdir(folder_path):
            if file == '.DS_Store':
                continue
            else:
                file_path = os.path.join(folder_path, file)
                
                # Check if the file name contains the "_aug" suffix
                if "_aug" in file:
                    augmented_images.append(file_path)

# Randomly select 10 augmented images
selected_images = random.sample(augmented_images, 10)

# Display the selected augmented images
plt.figure(figsize=(15, 8))
for i, image_path in enumerate(selected_images):
    image = tf.keras.preprocessing.image.load_img(image_path)
    image = tf.keras.preprocessing.image.img_to_array(image)

    plt.subplot(2, 5, i + 1)
    plt.imshow(image.astype('uint8'))
    plt.title('Augmented {}'.format(i + 1))
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
#get number of instances in folders in folder
def get_num_instances(folder):
  num_instances = [len(os.listdir(folder + '/' + i)) for i in os.listdir(folder)]
#return the number of instances
  return num_instances

# %% [markdown]
# ## Build Model

# %%
# Set a random seed
tf.random.set_seed(123)

# %%
#create imagegenerator and load images, taking some images to create validation and training dataset
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

#create training dataset
train_generator = image_generator.flow_from_directory(
    '/content/MachineLearning/Dataset/train_set_augmented_random',
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical') 

#create validation dataset
validation_generator = image_generator.flow_from_directory(
    '/content/MachineLearning/Dataset/valid_set', 
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical') 

#create test dataset
test_generator = tf.keras.utils.image_dataset_from_directory(
    '/content/MachineLearning/Dataset/test_set',
    image_size=(64, 64),
    batch_size=32,
    labels='inferred',
    label_mode='categorical')

test_generator = test_generator.map(lambda x, y: (x / 255.0, y))
# Out:
# Found 46430 images belonging to 32 classes.
# Found 18812 images belonging to 32 classes.
# Found 18839 files belonging to 32 classes.

# %% [markdown]
# ### Simple CNN

# %%
#define simple CNN the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(64, 64, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(32, activation='softmax')
])

# compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

early_stop = EarlyStopping(patience=2, monitor='val_loss', mode='min', verbose=1)

# %%
# Start the timer
start_time = time.perf_counter()
# Get initial CPU times
initial_cpu_times = psutil.cpu_times()
# Get the current process ID
process_id = psutil.Process().pid

# train the model
history = model.fit_generator(
    train_generator,
    steps_per_epoch=200,
    epochs=500,
    validation_data=validation_generator,
    validation_steps=100, 
    callbacks=[early_stop])

# Stop the timer
end_time = time.perf_counter()
# Get final CPU times
final_cpu_times = psutil.cpu_times()
# Get the memory usage of the current process
memory_info = psutil.Process(process_id).memory_info()
# Out:
# Epoch 1/500
# <ipython-input-126-2eb4f8ae7379>:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 200/200 [==============================] - 14s 65ms/step - loss: 3.1946 - accuracy: 0.1128 - val_loss: 2.3909 - val_accuracy: 0.3609
# Epoch 2/500
# 200/200 [==============================] - 13s 63ms/step - loss: 2.0009 - accuracy: 0.4073 - val_loss: 1.4345 - val_accuracy: 0.6500
# Epoch 3/500
# 200/200 [==============================] - 13s 63ms/step - loss: 1.3625 - accuracy: 0.5817 - val_loss: 0.8909 - val_accuracy: 0.7950
# Epoch 4/500
# 200/200 [==============================] - 12s 62ms/step - loss: 1.0598 - accuracy: 0.6808 - val_loss: 0.7074 - val_accuracy: 0.8169
# Epoch 5/500
# 200/200 [==============================] - 13s 63ms/step - loss: 0.8878 - accuracy: 0.7300 - val_loss: 0.5643 - val_accuracy: 0.8691
# Epoch 6/500
# 200/200 [==============================] - 13s 64ms/step - loss: 0.7749 - accuracy: 0.7617 - val_loss: 0.4614 - val_accuracy: 0.9022
# Epoch 7/500
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6867 - accuracy: 0.7934 - val_loss: 0.4008 - val_accuracy: 0.9038
# Epoch 8/500
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6531 - accuracy: 0.8053 - val_loss: 0.3619 - val_accuracy: 0.9178
# Epoch 9/500
# 200/200 [==============================] - 13s 65ms/step - loss: 0.5675 - accuracy: 0.8231 - val_loss: 0.3142 - val_accuracy: 0.9303
# Epoch 10/500
# 200/200 [==============================] - 13s 64ms/step - loss: 0.5322 - accuracy: 0.8366 - val_loss: 0.3101 - val_accuracy: 0.9397
# Epoch 11/500
# 200/200 [==============================] - 13s 63ms/step - loss: 0.5067 - accuracy: 0.8480 - val_loss: 0.2557 - val_accuracy: 0.9472
# Epoch 12/500
# 200/200 [==============================] - 12s 62ms/step - loss: 0.4611 - accuracy: 0.8583 - val_loss: 0.2481 - val_accuracy: 0.9516
# Epoch 13/500
# 200/200 [==============================] - 12s 62ms/step - loss: 0.4267 - accuracy: 0.8709 - val_loss: 0.2366 - val_accuracy: 0.9500
# Epoch 14/500
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3954 - accuracy: 0.8761 - val_loss: 0.2278 - val_accuracy: 0.9494
# Epoch 15/500
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3912 - accuracy: 0.8770 - val_loss: 0.2280 - val_accuracy: 0.9509
# Epoch 16/500
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3806 - accuracy: 0.8832 - val_loss: 0.2045 - val_accuracy: 0.9578
# Epoch 17/500
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3599 - accuracy: 0.8864 - val_loss: 0.1751 - val_accuracy: 0.9650
# Epoch 18/500
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3315 - accuracy: 0.8964 - val_loss: 0.1825 - val_accuracy: 0.9616
# Epoch 19/500
# 200/200 [==============================] - 13s 63ms/step - loss: 0.3168 - accuracy: 0.9067 - val_loss: 0.2012 - val_accuracy: 0.9572
# Epoch 19: early stopping

# %%
# Calculate running time
running_time_simple = (end_time - start_time) / 60

# Calculate CPU usage
cpu_user_time = final_cpu_times.user - initial_cpu_times.user
cpu_system_time = final_cpu_times.system - initial_cpu_times.system
cpu_idle_time = final_cpu_times.idle - initial_cpu_times.idle

total_cpu_time = cpu_user_time + cpu_system_time + cpu_idle_time
cpu_usage_simple = (cpu_user_time + cpu_system_time) / total_cpu_time

# Calculate the absolute memory usage in bytes
absolute_memory_usage_simple = memory_info.rss

# Convert the memory usage to a human-readable format
memory_usage_human_simple = psutil._common.bytes2human(absolute_memory_usage_simple)

# Print the results
print("Running Time: {:.2f} minutes".format(running_time_simple))
print("CPU Usage: {:.2f} seconds".format(cpu_usage_simple))
print("Absolute Memory Usage: {} ({} bytes)".format(memory_usage_human_simple, absolute_memory_usage_simple))
# Out:
# Running Time: 5.84 minutes
# CPU Usage: 0.61 seconds
# Absolute Memory Usage: 4.4G (4728020992 bytes)

# %%
# Prepare the data
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))

# Define the colors
colors = ['#a1c9f4', '#ffb6c1']  # Hexadecimal color codes for baby blue and baby green, respectively

# Plot accuracy
plt.plot(epochs, acc, color=colors[0], label='Training accuracy')
plt.plot(epochs, val_acc, color=colors[1], label='Validation accuracy')

plt.title('Training and validation accuracy of Simple CNN')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(test_generator)

print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)
# Out:
# 589/589 [==============================] - 9s 15ms/step - loss: 0.2088 - accuracy: 0.9579
# Test loss: 0.20884530246257782
# Test accuracy: 0.9579064846038818

# %%
#for printing classification report, store labels and images in lists
labels = []
images = []
#extract images and labels from all batches in test set
for image_batch, label_batch in tqdm(test_generator):
    images.append(image_batch)
    labels.append(label_batch)
# Out:
# 100%|██████████| 589/589 [00:01<00:00, 339.39it/s]

# %%
#concatenate all images and labels
images = np.concatenate(images)
labels = np.concatenate(labels)

#predict labels for test set
y_pred_model = model.predict(images)

#convert labels to integers
y_pred_m = np.argmax(y_pred_model, axis=1)
y_true = np.argmax(labels, axis=1)

#plot classification report
print(classification_report(y_true, y_pred_m))

# Print the confusion matrix
print(confusion_matrix(y_true, y_pred_m))

#plot confusion matrix
cm = confusion_matrix(y_true, y_pred_m)
plt.figure(figsize=(10,10))
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# 589/589 [==============================] - 8s 13ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       857
#            1       0.99      0.96      0.97       444
#            2       0.92      0.95      0.94       507
#            3       0.98      0.94      0.96       644
#            4       0.98      0.95      0.96       636
#            5       0.98      0.98      0.98       631
#            6       0.99      0.96      0.97       547
#            7       0.94      0.90      0.92       718
#            8       0.89      0.91      0.90       620
#            9       0.99      0.97      0.98       776
#           10       0.93      0.95      0.94       622
#           11       0.94      0.94      0.94       586
#           12       0.91      0.95      0.93       548
#           13       0.91      0.94      0.92       493
#           14       0.94      0.95      0.95       599
#           15       0.98      0.98      0.98       575
#           16       0.95      0.97      0.96       646
#           17       0.97      0.98      0.98       632
#           18       0.97      0.98      0.98       636
#           19       0.95      0.97      0.96       657
#           20       0.97      0.94      0.95       632
#           21       0.93      0.97      0.95       369
#           22       0.98      0.96      0.97       437
#           23       0.98      0.97      0.97       720
#           24       0.96      0.93      0.94       556
#           25       0.86      0.97      0.91       538
#           26       0.98      0.93      0.95       574
#           27       0.99      0.97      0.98       633
#           28       0.97      0.96      0.97       387
#           29       0.99      0.98      0.99       582
#           30       0.98      1.00      0.99       507
#           31       0.95      0.96      0.96       530
#
#     accuracy                           0.96     18839
#    macro avg       0.96      0.96      0.96     18839
# weighted avg       0.96      0.96      0.96     18839
#
# [[851   0   0 ...   0   0   0]
#  [  0 426   0 ...   0   0   0]
#  [  0   1 484 ...   1   0   0]
#  ...
#  [  0   0   0 ... 571   1   0]
#  [  0   0   1 ...   0 506   0]
#  [  0   0   0 ...   0   0 509]]

# %%
# Find misclassified samples
misclassified_indices = np.where(y_true != y_pred_m)[0]

# Get the most common misclassified class
most_common_misclass = np.argmax(np.bincount(y_true[misclassified_indices]))

# Get the indices of misclassified samples for the most common class
misclassified_indices_class = misclassified_indices[y_true[misclassified_indices] == most_common_misclass]

# Plot a selection of the misclassified images
num_samples_to_plot = 5
fig, axes = plt.subplots(1, num_samples_to_plot, figsize=(15, 3))

for i, index in enumerate(misclassified_indices_class[:num_samples_to_plot]):
    image = images[index]
    true_label = y_true[index]
    predicted_label = y_pred_m[index]
    
    axes[i].imshow(image)
    axes[i].set_title(f"True: {true_label}, Predicted: {predicted_label}")
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Complex CNN

# %%
model_complex = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), input_shape=(64, 64, 3)),
    LeakyReLU(alpha=0.1),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv2D(32, (3,3)),
    LeakyReLU(alpha=0.1),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3)),
    LeakyReLU(alpha=0.1),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3)),
    LeakyReLU(alpha=0.1),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512),
    LeakyReLU(alpha=0.1),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(32, activation='softmax')
])

# Define a function that returns the learning rate as a function of the epoch number
def lr_schedule(epoch):
    lr = 0.001
    if epoch > 10:
        lr *= 0.5
    if epoch > 20:
        lr *= 0.5
    return lr

# Create the Adam optimizer and the learning rate scheduler
adam = Adam(learning_rate=0.001)
lr_scheduler = LearningRateScheduler(lr_schedule)

# compile the model
model_complex.compile(optimizer=adam,
                loss='categorical_crossentropy',
                metrics=['accuracy'])

early_stop = EarlyStopping(patience=5, monitor='val_loss', mode='min', verbose=1)

# %%
# Start the timer
start_time = time.perf_counter()
# Get initial CPU times
initial_cpu_times = psutil.cpu_times()
# Get the current process ID
process_id = psutil.Process().pid

# train the model
history_complex = model_complex.fit_generator(
    train_generator,
    steps_per_epoch=200,
    epochs=500,
    validation_data=validation_generator,
    validation_steps=100,
    callbacks=[early_stop, lr_scheduler])

# Stop the timer
end_time = time.perf_counter()
# Get final CPU times
final_cpu_times = psutil.cpu_times()
# Get the memory usage of the current process
memory_info = psutil.Process(process_id).memory_info()
# Out:
# Epoch 1/500
# <ipython-input-134-4e7bd692f73d>:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_complex = model_complex.fit_generator(
# 200/200 [==============================] - 18s 81ms/step - loss: 2.8416 - accuracy: 0.2261 - val_loss: 5.0500 - val_accuracy: 0.0284 - lr: 0.0010
# Epoch 2/500
# 200/200 [==============================] - 16s 79ms/step - loss: 1.7030 - accuracy: 0.4764 - val_loss: 3.7204 - val_accuracy: 0.2041 - lr: 0.0010

# %%
# Calculate running time
running_time_complex = (end_time - start_time) / 60

# Calculate CPU usage
cpu_user_time = final_cpu_times.user - initial_cpu_times.user
cpu_system_time = final_cpu_times.system - initial_cpu_times.system
cpu_idle_time = final_cpu_times.idle - initial_cpu_times.idle

total_cpu_time = cpu_user_time + cpu_system_time + cpu_idle_time
cpu_usage_complex = (cpu_user_time + cpu_system_time) / total_cpu_time

# Calculate the absolute memory usage in bytes
absolute_memory_usage_complex = memory_info.rss

# Convert the memory usage to a human-readable format
memory_usage_human_complex = psutil._common.bytes2human(absolute_memory_usage_complex)

# Print the results
print("Running Time: {:.2f} minutes".format(running_time_complex))
print("CPU Usage: {:.2f} seconds".format(cpu_usage_complex))
print("Absolute Memory Usage: {} ({} bytes)".format(memory_usage_human_complex, absolute_memory_usage_complex))

# %%
# Prepare the data
acc = history_complex.history['accuracy']
val_acc = history_complex.history['val_accuracy']
loss = history_complex.history['loss']
val_loss = history_complex.history['val_loss']
epochs = range(len(acc))

# Define the colors
colors = ['#a1c9f4', '#ffb6c1']  # Hexadecimal color codes for baby blue and baby pink, respectively

# Plot accuracy
plt.plot(epochs, acc, color=colors[0], label='Training accuracy')
plt.plot(epochs, val_acc, color=colors[1], label='Validation accuracy')

plt.title('Training and validation accuracy of Complex CNN')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model_complex.evaluate(test_generator)

print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)

# %%
#predict labels for test set
y_pred_model_complex = model_complex.predict(images)

#convert labels to integers
y_pred_m_comp = np.argmax(y_pred_model_complex, axis=1)
y_true = np.argmax(labels, axis=1)

#plot classification report
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred_m_comp))

# Print the confusion matrix
print(confusion_matrix(y_true, y_pred_m_comp))

#plot confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, y_pred_m_comp)
plt.figure(figsize=(10,10))
sns.heatmap(cm, annot=True, fmt="d")
plt.show()

# %%
# Find misclassified samples
misclassified_indices = np.where(y_true != y_pred_m_comp)[0]

# Get the most common misclassified class
most_common_misclass = np.argmax(np.bincount(y_true[misclassified_indices]))

# Get the indices of misclassified samples for the most common class
misclassified_indices_class = misclassified_indices[y_true[misclassified_indices] == most_common_misclass]

# Plot a selection of the misclassified images
num_samples_to_plot = 5
fig, axes = plt.subplots(1, num_samples_to_plot, figsize=(15, 3))

for i, index in enumerate(misclassified_indices_class[:num_samples_to_plot]):
    image = images[index]
    true_label = y_true[index]
    predicted_label = y_pred_m_comp[index]
    
    axes[i].imshow(image)
    axes[i].set_title(f"True: {true_label}, Predicted: {predicted_label}")
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### GoogLeNet Inspired CNN

# %%
# Define the GoogLeNet-inspired CNN model
def googlenet(input_shape, num_classes):
    inputs = tf.keras.Input(shape=input_shape)

    # Stage 1
    x = layers.Conv2D(64, kernel_size=7, strides=2, padding='same', activation='relu')(inputs)
    x = layers.MaxPooling2D(pool_size=3, strides=2, padding='same')(x)
    x = layers.BatchNormalization()(x)

    # Stage 2
    x = layers.Conv2D(64, kernel_size=1, activation='relu')(x)
    x = layers.Conv2D(192, kernel_size=3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(pool_size=3, strides=2, padding='same')(x)

    # Stage 3 (Inception modules)
    # Inception module 1
    x = inception_module(x, 64, 96, 128, 16, 32, 32)
    # Inception module 2
    x = inception_module(x, 128, 128, 192, 32, 96, 64)

    # Add more inception modules as needed...

    # Final layers
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(1024, activation='relu')(x)
    x = layers.Dropout(0.4)(x)  # Optional: Add a dropout layer for regularization
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    # Create the model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    return model

# Helper function to create an inception module
def inception_module(x, filters_1x1, filters_3x3_reduce, filters_3x3, filters_5x5_reduce, filters_5x5, filters_pool_proj):
    conv_1x1 = layers.Conv2D(filters_1x1, kernel_size=1, activation='relu')(x)
    conv_3x3_reduce = layers.Conv2D(filters_3x3_reduce, kernel_size=1, activation='relu')(x)
    conv_3x3 = layers.Conv2D(filters_3x3, kernel_size=3, padding='same', activation='relu')(conv_3x3_reduce)
    conv_5x5_reduce = layers.Conv2D(filters_5x5_reduce, kernel_size=1, activation='relu')(x)
    conv_5x5 = layers.Conv2D(filters_5x5, kernel_size=5, padding='same', activation='relu')(conv_5x5_reduce)
    pool_proj = layers.Conv2D(filters_pool_proj, kernel_size=1, activation='relu')(x)

    output = layers.concatenate([conv_1x1, conv_3x3, conv_5x5, pool_proj], axis=-1)
    return output

# %%
# Define the input shape
input_shape = (64, 64, 3)
model = googlenet(input_shape, 32)

#Compile the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

early_stopping = EarlyStopping(patience=3, restore_best_weights=True)

# %%
# Start the timer
start_time = time.perf_counter()
# Get initial CPU times
initial_cpu_times = psutil.cpu_times()
# Get the current process ID
process_id = psutil.Process().pid


history_googlenet = model.fit(
    train_generator,
    steps_per_epoch=train_generator.n // train_generator.batch_size,
    epochs=15,
    validation_data=validation_generator,
    validation_steps=validation_generator.n // validation_generator.batch_size,
    callbacks=[early_stopping]
)


# Stop the timer
end_time = time.perf_counter()
# Get final CPU times
final_cpu_times = psutil.cpu_times()
# Get the memory usage of the current process
memory_info = psutil.Process(process_id).memory_info()
# Out:
# Epoch 1/15
# 1450/1450 [==============================] - 286s 196ms/step - loss: 1.2305 - accuracy: 0.6154 - val_loss: 0.9187 - val_accuracy: 0.7266
# Epoch 2/15
# 1450/1450 [==============================] - 269s 185ms/step - loss: 0.3348 - accuracy: 0.8947 - val_loss: 0.3354 - val_accuracy: 0.9042
# Epoch 3/15
# 1450/1450 [==============================] - 282s 195ms/step - loss: 0.2158 - accuracy: 0.9326 - val_loss: 0.2693 - val_accuracy: 0.9213

# %%
# Calculate running time
running_time_googlenet = (end_time - start_time) / 60

# Calculate CPU usage
cpu_user_time = final_cpu_times.user - initial_cpu_times.user
cpu_system_time = final_cpu_times.system - initial_cpu_times.system
cpu_idle_time = final_cpu_times.idle - initial_cpu_times.idle

total_cpu_time = cpu_user_time + cpu_system_time + cpu_idle_time
cpu_usage_googlenet = (cpu_user_time + cpu_system_time) / total_cpu_time

# Calculate the absolute memory usage in bytes
absolute_memory_usage_googlenet = memory_info.rss

# Convert the memory usage to a human-readable format
memory_usage_human_googlenet = psutil._common.bytes2human(absolute_memory_usage_googlenet)

# Print the results
print("Running Time: {:.2f} minutes".format(running_time_googlenet))
print("CPU Usage: {:.2f} seconds".format(cpu_usage_googlenet))
print("Absolute Memory Usage: {} ({} bytes)".format(memory_usage_human_googlenet, absolute_memory_usage_googlenet))

# %%
# Prepare the data
acc = history_googlenet.history['accuracy']
val_acc = history_googlenet.history['val_accuracy']
loss = history_googlenet.history['loss']
val_loss = history_googlenet.history['val_loss']
epochs = range(len(acc))

# Define the colors
colors = ['#a1c9f4', '#ffb6c1']  # Hexadecimal color codes for blue and pink, respectively

# Plot accuracy
plt.plot(epochs, acc, color=colors[0], label='Training accuracy')
plt.plot(epochs, val_acc, color=colors[1], label='Validation accuracy')

plt.title('Training and validation accuracy of GoogLeNet Inspired CNN')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(test_generator)

print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)

# %%
#predict labels for test set
y_pred_model= model.predict(images)

#convert labels to integers
y_pred_m_googlenet = np.argmax(y_pred_model, axis=1)
y_true = np.argmax(labels, axis=1)

#plot classification report
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred_m_googlenet))

# Print the confusion matrix
print(confusion_matrix(y_true, y_pred_m_googlenet))

#plot confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, y_pred_m_googlenet)
plt.figure(figsize=(10,10))
sns.heatmap(cm, annot=True, fmt="d")
plt.show()

# %%
# Find misclassified samples
misclassified_indices = np.where(y_true != y_pred_m_googlenet)[0]

# Get the most common misclassified class
most_common_misclass = np.argmax(np.bincount(y_true[misclassified_indices]))

# Get the indices of misclassified samples for the most common class
misclassified_indices_class = misclassified_indices[y_true[misclassified_indices] == most_common_misclass]

# Plot a selection of the misclassified images
num_samples_to_plot = 5
fig, axes = plt.subplots(1, num_samples_to_plot, figsize=(15, 3))

for i, index in enumerate(misclassified_indices_class[:num_samples_to_plot]):
    image = images[index]
    true_label = y_true[index]
    predicted_label = y_pred_m_googlenet[index]
    
    axes[i].imshow(image)
    axes[i].set_title(f"True: {true_label}, Predicted: {predicted_label}")
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Comparison computational metrics

# %%
# Prepare the data
labels = ['Memory Usage Simple CNN', 'Memory Usage Complex CNN', 'Memory Usage GoogLeNet']
values = [memory_usage_human_simple, memory_usage_human_complex, memory_usage_human_googlenet]

# Define the colors
colors = ['#a1c9f4', '#ffb6c1', '#b7e4b4']  # Hexadecimal color codes for baby blue, baby pink, and baby green, respectively

# Create a bar plot
plt.bar(labels, values, color=colors)
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.title('Memory Usage Models')

# Rotate the x-axis labels
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
# Prepare the data
labels = ['CPU Usage Simple CNN', 'CPU Usage Complex CNN', 'CPU Usage GoogLeNet']
values = [cpu_usage_simple, cpu_usage_complex, cpu_usage_googlenet]

# Define the colors
colors = ['#a1c9f4', '#ffb6c1', '#b7e4b4']  # Hexadecimal color codes for baby blue, baby pink, and baby green, respectively

# Create a bar plot
plt.bar(labels, values, color=colors)
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.title('CPU Usage Models')

# Rotate the x-axis labels
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
# Prepare the data
labels = ['Running Time Simple CNN', 'Running Time Complex CNN', 'Running Time GoogLeNet']
values = [running_time_simple, running_time_complex, running_time_googlenet]

# Define the colors
colors = ['#a1c9f4', '#ffb6c1', '#b7e4b4']  # Hexadecimal color codes for baby blue, baby pink, and baby green, respectively

# Create a bar plot
plt.bar(labels, values, color=colors)
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.title('Running Time Models')

# Rotate the x-axis labels
plt.xticks(rotation=45)

# Show the plot
plt.show()
