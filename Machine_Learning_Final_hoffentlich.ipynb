# %% [markdown]
# <a href="https://colab.research.google.com/github/inesfrsantos/MachineLearning/blob/main/Machine_Learning_Final_hoffentlich.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Analysis and Preprocessing
# ## Load needed packages and Data

# %%
import pandas as pd
import os
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
import hashlib

# %%
# Data is stored in a GitHub Repository
# !git clone https://github.com/inesfrsantos/MachineLearning.git
# Out:
# Cloning into 'MachineLearning'...
# remote: Enumerating objects: 48639, done.
# remote: Total 48639 (delta 0), reused 0 (delta 0), pack-reused 48639
# Receiving objects: 100% (48639/48639), 113.30 MiB | 1.55 MiB/s, done.
# Resolving deltas: 100% (2213/2213), done.
# Updating files: 100% (185412/185412), done.

# %%
# !ls
# Out:
# MachineLearning  sample_data

# %%
path = "/content/MachineLearning/Dataset/ArASL_Database_54K_Final"

# %%
# create empty lists to store image file paths, images, and labels
img_path = []
images = []
labels = []

# loop through each folder in the path
for folder_name in os.listdir(path):
    # create the full path to the folder
    folder_path = os.path.join(path, folder_name)
    # skip any non-directory files
    if not os.path.isdir(folder_path):
        continue
    # loop through each file in the folder
    for file_name in os.listdir(folder_path):
        # check if the file is a jpg, png, JPG, or PNG file
        if file_name.endswith(".jpg") or file_name.endswith(".png") or file_name.endswith(".JPG") or file_name.endswith(".PNG"):
            # create the full path to the image file
            image_path = os.path.join(folder_path, file_name)
            # check if the file is a regular file
            if os.path.isfile(image_path):
                # open the image file and convert it to grayscale
                image = Image.open(image_path).convert('L')
                # append the image file path, image, and label to their respective lists
                images.append(image)
                labels.append(folder_name)
                img_path.append(image_path)

# create a pandas dataframe with the image file paths, images, and labels as columns
df = pd.DataFrame({'img_path': img_path, 'image': images, 'label': labels})

# %% [markdown]
# ## Exploratory Analysis

# %%
#get the total number of pictures in the dataset
num_pics = len(df)
print("Number of pictures in the dataset:\n")
print(num_pics, "\n")

#get the total number of pictures per category and the corresponding percentage
label_counts = df['label'].value_counts()
print("Number and Percentage of pictures per Label:\n")
for label, count in label_counts.items():
    percentage = count/num_pics * 100
    print(f"{label}: {count} ({percentage:.2f}%)")
# Out:
# Number of pictures in the dataset:
#
# 38645
#
# Number and Percentage of pictures per Label:
#
# ain: 1771 (4.58%)
# ghain: 1564 (4.05%)
# fa: 1464 (3.79%)
# ta: 1454 (3.76%)
# nun: 1342 (3.47%)
# laam: 1326 (3.43%)
# ra: 1321 (3.42%)
# bb: 1311 (3.39%)
# dal: 1308 (3.38%)
# dha: 1297 (3.36%)
# gaaf: 1296 (3.35%)
# toot: 1281 (3.31%)
# meem: 1277 (3.30%)
# ha: 1274 (3.30%)
# saad: 1270 (3.29%)
# khaa: 1245 (3.22%)
# ya: 1228 (3.18%)
# haa: 1191 (3.08%)
# la: 1178 (3.05%)
# thal: 1177 (3.05%)
# taa: 1163 (3.01%)
# dhad: 1137 (2.94%)
# jeem: 1108 (2.87%)
# thaa: 1108 (2.87%)
# zay: 1108 (2.87%)
# yaa: 1063 (2.75%)
# kaaf: 1029 (2.66%)
# aleff: 1018 (2.63%)
# sheen: 898 (2.32%)
# al: 896 (2.32%)
# waw: 785 (2.03%)
# seen: 757 (1.96%)

# %%
# plot the count of images per Label
# Get unique labels from the dataframe
Label = df['label'].unique()

# Set the size of the plot
plt.figure(figsize=(16,4))

# Create a bar chart of label counts
plt.bar(range(len(label_counts)), label_counts, alpha = .7)

# Set x-axis tick marks and labels to the unique labels
plt.xticks(range(len(label_counts)), Label, rotation = 45)

# Set x and y axis labels
plt.xlabel("Label")
plt.ylabel("Amount")

# Display the plot
plt.show()

# %%
# Plot Examples of all signs with theri best quality
# Get one image for each label
label_to_image = {}
for label in df['label'].unique():
    label_df = df[df['label'] == label]
    variances = [np.var(np.array(image)) for image in label_df['image']]
    max_idx = np.argmax(variances)
    label_to_image[label] = label_df.iloc[max_idx]['image']

# Create a figure with subplots
fig, axs = plt.subplots(nrows=int(np.ceil(len(label_to_image) / 8)), ncols=8, figsize=(32, 12))

# Loop over each label and plot the corresponding image
for i, (label, image) in enumerate(label_to_image.items()):
    row = i // 8
    col = i % 8
    axs[row, col].imshow(image, cmap='gray')
    axs[row, col].set_title(label, fontsize=20)
    axs[row, col].axis('off')

# Adjust spacing and display the plot
fig.tight_layout()
plt.show()

# %%
# plot the square root size vs aspect ratio to see the distribution of sizes
# first calculate the square root size and the aspect ratio
square_root_size = []
aspect_ratio = []
for image in df['image']:
  #size of the images in pixels
  width, height = image.size
  
  #calculate the square root size
  sqrt_size = (width * height) ** 0.5
  square_root_size.append(sqrt_size)

  #cxalculate the aspect_ration
  aspt_rt = width/height
  aspect_ratio.append(aspt_rt)

# plot the data
fig, ax = plt.subplots()
ax.scatter(aspect_ratio, square_root_size)

# add labels and a title
ax.set_xlabel("aspect ratio")
ax.set_ylabel("square root size")
ax.set_title("square root size vs. aspect ratio")

# show the plot
plt.show()

# %%
df['aspect_ratio'] = aspect_ratio
df['square_root_size'] = square_root_size

# %%
# Calculate the number of images with different aspect ratios than 1:1.
num_dif_ratio = len(np.where(df['aspect_ratio'] != 1)[0])
print(f"Number of different ratio: {num_dif_ratio}")
# Out:
# Number of different ratio: 10

# %%
#reduce the dataframe to the rows that have a different aspect ratio than 1
df_asp = df.loc[df['aspect_ratio'] != 1]

# Define the number of columns in the figure
num_cols = 5

# Calculate the number of rows needed
num_rows = len(df_asp) // num_cols

# Create a new figure
fig, axes = plt.subplots(num_rows, num_cols, figsize=(32, 12))

# Flatten the axes array for ease of iteration
axes = axes.flatten()

# Loop through each image in the DataFrame and display it
for i, (_, row) in enumerate(df_asp.iterrows()):
    img = row['image']
    ax = axes[i]
    ax.imshow(img, cmap='gray')
    ax.set_title(row['label'])
    ax.axis('off')
    
# Remove any unused axes
for i in range(len(df), num_rows * num_cols):
    axes[i].axis('off')
    
plt.tight_layout()
plt.show()

# %%
# Find rows where the image size is not (64,64)
non_6464_rows = df[df['image'].apply(lambda x: x.size) != (64,64)]

#get the total number of pictures that are not size (64,64)
num_pics_64 = len(non_6464_rows)
num_pics = len(df)
Perc_of_whole = num_pics_64/num_pics * 100
print("Number of pictures with different size:\n")
print(num_pics_64)
print("That is", f"{Perc_of_whole:.2f}%", "of the whole dataset \n")

#split the information per category
label_counts_64 = non_6464_rows['label'].value_counts()
label_counts = df['label'].value_counts()
print("Number and Percentage of different sized pictures per Label:")
print("(The Percentage refers to the number of all pictures of that label):\n")
for label, count in label_counts_64.items():
    percentage = count/label_counts[label] * 100
    print(f"{label}: {count} ({percentage:.2f}%)")
# Out:
# Number of pictures with different size:
#
# 33
# That is 0.09% of the whole dataset
#
# Number and Percentage of different sized pictures per Label:
# (The Percentage refers to the number of all pictures of that label):
#
# meem: 13 (1.02%)
# kaaf: 10 (0.97%)
# haa: 10 (0.84%)

# %%
# Color Channel Analysis
def get_channel_means(image):
    return np.mean(np.array(image))
# Initialize a list to store the mean pixel intensity of each color channel
channel_means = []

# Loop through the images in the dataset and calculate the channel means
for i in range(len(df)):
    image = df['image'][i]
    channel_means.append(get_channel_means(image))

# Convert the channel means to a numpy array and calculate the mean and standard deviation for the channel
channel_means = np.array(channel_means)
mean_intensity = np.mean(channel_means)
std_intensity = np.std(channel_means)

# Print the mean and standard deviation for the channel
print("Mean pixel intensity: {:.2f}".format(mean_intensity))
print("Standard deviation of pixel intensity: {:.2f}".format(std_intensity))
# Out:
# Mean pixel intensity: 181.31
# Standard deviation of pixel intensity: 28.93

# %% [markdown]
# ## Preprocessing

# %%
filtered_images = []

# %%
# Check for Duplicates

def get_hash(img_path):
    """
    Calculates the MD5 checksum of the input image.

    Args:
        img_path (str): The file path of the input image.

    Returns:
        str: The MD5 checksum of the image.
    """
    # Open the input image in binary mode
    with open(img_path, "rb") as f:
        # Initialize a new MD5 hash object
        img_hash = hashlib.md5()
        # Read the image data in chunks and update the hash object with each chunk
        while chunk := f.read(8192):
           img_hash.update(chunk)
    # Return the hexadecimal representation of the hash value
    return img_hash.hexdigest()

# %%
#Add a column to the DataFrame to store the hash values for each image in the dataset
df['hash'] = df['img_path'].apply(get_hash)

#Calculate the number of unique hash values in the dataset and identify duplicates based on the hash value
unique_values = df['hash'].nunique()
duplicates = df[df.duplicated(['hash'])]

#Print the number of duplicates found in the dataset
print("Duplicates in the Dataset based on the calculated hash value:")
print(len(duplicates), '\n')

#Print the total number of images in the dataset before dropping duplicates
print("Images in the Dataset before dropping Duplicates:")
print(len(df), '\n')

#Drop the duplicate images from the dataset based on the hash value and reset the index
df.drop_duplicates(subset=['hash'], inplace=True)
df = df.reset_index(drop=True)

#Print the total number of images in the dataset after dropping duplicates
print("Images in the Dataset after dropping Duplicates:")
print(len(df))

image_path = duplicates['img_path']
print(image_path)
for path in image_path:
  filtered_images.append(path)

print(len(filtered_images))
# Out:
# Duplicates in the Dataset based on the calculated hash value:
# 0
#
# Images in the Dataset before dropping Duplicates:
# 38645
#
# Images in the Dataset after dropping Duplicates:
# 38645
# Series([], Name: img_path, dtype: object)
# 0

# %%
# Create an empty list to store the anomaly scores for each image
anomaly_scores = []

# Loop through each image in the dataset
for i in range(len(df)):
    # Load the image
    image = df.loc[i, 'image']
    
    # Calculate the mean and standard deviation of the image
    mean = np.mean(image)
    std = np.std(image)
    
    # Calculate the anomaly score
    anomaly_score = np.abs((image - mean) / std).mean()
    anomaly_scores.append(anomaly_score)

# Add the anomaly scores as a new column to the dataframe
df['anomaly_score'] = anomaly_scores

# Print the dataframe sorted by anomaly score
print(df.sort_values(by='anomaly_score', ascending=False))
# Out:
#                                                 img_path  \
# 15468  /content/MachineLearning/Dataset/ArASL_Databas...
# 30128  /content/MachineLearning/Dataset/ArASL_Databas...
# 21720  /content/MachineLearning/Dataset/ArASL_Databas...
# 23859  /content/MachineLearning/Dataset/ArASL_Databas...
# 30576  /content/MachineLearning/Dataset/ArASL_Databas...
# ...                                                  ...
# 34418  /content/MachineLearning/Dataset/ArASL_Databas...
# 23078  /content/MachineLearning/Dataset/ArASL_Databas...
# 21759  /content/MachineLearning/Dataset/ArASL_Databas...
# 21791  /content/MachineLearning/Dataset/ArASL_Databas...
# 26661  /content/MachineLearning/Dataset/ArASL_Databas...
#
#                                                    image  label  aspect_ratio  \
# 15468  <PIL.Image.Image image mode=L size=64x64 at 0x...  ghain           1.0
# 30128  <PIL.Image.Image image mode=L size=64x64 at 0x...    dha           1.0
# 21720  <PIL.Image.Image image mode=L size=64x64 at 0x...    taa           1.0
# 23859  <PIL.Image.Image image mode=L size=64x64 at 0x...   laam           1.0
# 30576  <PIL.Image.Image image mode=L size=64x64 at 0x...    dha           1.0
# ...                                                  ...    ...           ...
# 34418  <PIL.Image.Image image mode=L size=64x64 at 0x...   meem           1.0
# 23078  <PIL.Image.Image image mode=L size=64x64 at 0x...    waw           1.0
# 21759  <PIL.Image.Image image mode=L size=64x64 at 0x...    taa           1.0
# 21791  <PIL.Image.Image image mode=L size=64x64 at 0x...    taa           1.0
# 26661  <PIL.Image.Image image mode=L size=64x64 at 0x...    dal           1.0
#
#        square_root_size                              hash  anomaly_score
# 15468              64.0  a8371eb309b5d6e213306f5e954fdc30       0.849997
# 30128              64.0  f467ebf7b53124fc8d81377abc8fbc9d       0.849997
# 21720              64.0  a3d80b8bd16bc8feacd035fa486b59bd       0.849993
# 23859              64.0  e60d9b831fe0496530e86f633b002524       0.849991
# 30576              64.0  899b72df71b297e9ca5233cca8599e97       0.849988
# ...                 ...                               ...            ...
# 34418              64.0  5c66354974afd5cb2daedc0a4ed2d73f       0.481937
# 23078              64.0  d16b91b1873051b3321f8da7bfe08ba4       0.475243
# 21759              64.0  b044cf9920e191d40f2a8eab4e763647       0.468129
# 21791              64.0  d182aaf6cddbda8a406a7534e66e2553       0.443558
# 26661              64.0  c65ff0291608e262755b32f0b82ddcf4       0.422069
#
# [38645 rows x 7 columns]

# %%
#Filter out images with anomaly scores above 0.85
anomal_img = df.loc[df['anomaly_score'] >= 0.85]
df_filtered = df.loc[df['anomaly_score'] < 0.85]

#Reset the index to start from 0
df_filtered = df_filtered.reset_index(drop=True)

#Print the number of images in the filtered dataset
print('Number of pictures in the dataset after filtering:')
print(len(df_filtered))

image_path = anomal_img['img_path']
for path in image_path:
  filtered_images.append(path)

print(len(filtered_images))
# Out:
# Number of pictures in the dataset after filtering:
# 38645
# 0

# %%
# filter the images from the train and test directories
for image_path in filtered_images:
  os.remove(image_path)

# %%
#!zip -r /content/MachineLearning/Dataset/filtered_Dataset.zip /content/MachineLearning/Dataset/ArASL_Database_54K_Final
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (180).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (84).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1627).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (594).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1201).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1456).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (27).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1073).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1229).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (555).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1142).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1064).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (584).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (914).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (669).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1398).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1421).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (810).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1102).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (175).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (473).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (684).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1150).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1361).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (256).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1032).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1639).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1576).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1328).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (675).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1593).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1249).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1082).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1416).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1399).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (193).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (588).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1162).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1379).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1170).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1658).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1194).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1621).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (671).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1267).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1523).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (67).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (633).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1238).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1208).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1476).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (854).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1001).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (142).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (539).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (137).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (912).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1136).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (62).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1067).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1143).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (6).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (251).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (115).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1661).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1206).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (534).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1649).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (47).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (559).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (264).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1047).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1386).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1583).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (274).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1477).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (31).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1464).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (833).JPG (deflated 4%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1316).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1432).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (629).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1134).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (489).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (237).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (637).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (843).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (553).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (642).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1634).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (174).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1696).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1648).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (113).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1092).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (165).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1228).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (99).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (2).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (971).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1235).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (55).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1687).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (162).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1139).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1534).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (741).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1295).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (246).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1632).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1413).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1077).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (558).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1357).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1296).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (831).JPG (deflated 4%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1257).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (592).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1680).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1666).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (888).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1334).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1671).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1034).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1198).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1005).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1407).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1704).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1161).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (526).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (479).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (581).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (999).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1384).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1152).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1504).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (870).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1000).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1492).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (621).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (972).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1470).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1659).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (996).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1453).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (106).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (141).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (899).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1060).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1698).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (493).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1448).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (909).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1455).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (58).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1321).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (181).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1495).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1341).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (486).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (860).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1040).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (729).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1226).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (600).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (622).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (906).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (147).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1237).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (725).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (228).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1546).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (24).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (416).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (900).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1024).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (442).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (529).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1311).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (145).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1505).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (661).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (704).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (587).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (9).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1701).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (509).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (60).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (791).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1193).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1430).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1347).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1326).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1479).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1728).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (620).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1231).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (498).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1251).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1549).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1075).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (154).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (680).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (108).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (609).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1003).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1435).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1427).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1535).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (253).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1578).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1585).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (863).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (946).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (815).JPG (deflated 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (635).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (53).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1042).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1080).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (414).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1729).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1539).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (692).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (184).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (653).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1004).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (993).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1675).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1266).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (213).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1629).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (896).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1099).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (664).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1406).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1031).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (728).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (114).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (528).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1503).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (103).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (232).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (682).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (128).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (82).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (585).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1562).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (34).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (640).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (257).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (76).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1375).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (125).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (272).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1263).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (892).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1624).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1732).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (577).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1362).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1685).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (607).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1475).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1103).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (950).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1498).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (17).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1105).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (63).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1703).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (66).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (171).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1078).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1175).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1068).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1645).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1515).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1307).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1242).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1358).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1630).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (631).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1414).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (224).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1364).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1132).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (269).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (188).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (105).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1276).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (65).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (263).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (501).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (857).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1258).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (500).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1584).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1155).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1216).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (136).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1636).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (38).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (610).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1222).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1631).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1048).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (557).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (627).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (70).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1286).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (589).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1552).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (163).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1119).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1628).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1444).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (121).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1587).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1588).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1650).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (644).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (628).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1526).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1151).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (580).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1158).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (885).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1014).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1665).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1071).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1106).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1088).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (613).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (81).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1308).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1642).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (883).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1488).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (710).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1425).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1166).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (86).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (482).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1387).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (170).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (947).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1355).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (686).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1683).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (951).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1240).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1438).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1100).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (674).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (974).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1372).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (537).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1069).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (166).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (734).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (164).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (608).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (651).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (91).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1586).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1377).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1050).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1352).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1380).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1177).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (618).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (16).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1126).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1440).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1381).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (74).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (711).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1351).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (566).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (72).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1225).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (702).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1164).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1066).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (168).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (21).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1121).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1651).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (716).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (85).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1318).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1279).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1016).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (994).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1037).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (185).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (112).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (243).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1652).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (68).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1446).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (689).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1252).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1293).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1480).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1368).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1725).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (476).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1107).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (624).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1163).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (858).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1594).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1312).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1443).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1297).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1408).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (266).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (148).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (48).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (660).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1234).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1313).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (905).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1189).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1002).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1035).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (611).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1323).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (626).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1445).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1708).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1028).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1204).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (5).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1727).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (252).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1726).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (522).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (19).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1214).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1558).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1467).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1521).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1191).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (673).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (793).JPG (deflated 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1346).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1289).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1532).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1669).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1065).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1233).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1405).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (96).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (270).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1382).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1681).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1333).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1688).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (533).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1354).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1402).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (690).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (144).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1090).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (510).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (871).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1215).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (212).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1087).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1083).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1012).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (554).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1564).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (606).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (890).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1036).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (488).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/meem/MEEM (1574).jpg (stored 0%)
# ...
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1036).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1630).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (658).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (327).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (259).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (956).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1605).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (665).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (965).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (638).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1133).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1431).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (273).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (985).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1405).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (703).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1068).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1009).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1234).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1195).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (946).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (897).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1173).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1426).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1457).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1490).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (900).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1591).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (635).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (812).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1053).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (706).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (677).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (672).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (71).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (247).jpg (deflated 23%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (725).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1152).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1480).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (889).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1435).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (712).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1483).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1611).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (624).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (239).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1225).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1336).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (693).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (31).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1513).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1142).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (166).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (353).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1658).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (277).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (850).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (929).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1359).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (762).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1482).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1150).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (335).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (857).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (260).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (64).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (138).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (719).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (799).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1012).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1499).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1307).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (42).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1078).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (37).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1488).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1261).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (822).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1415).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1311).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1069).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1266).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1098).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1129).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1646).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (982).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (617).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (935).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1627).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (769).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (235).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (17).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (188).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (700).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1337).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (923).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (777).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1241).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (838).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1470).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1325).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1061).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1250).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (169).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (820).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (26).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1117).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (715).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (340).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (662).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (683).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (823).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (66).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (36).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (287).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1066).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (632).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (934).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1514).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (771).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (100).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1519).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1144).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (248).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1000).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1596).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1452).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (970).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (734).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (790).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (578).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (231).jpg (deflated 23%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (990).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (55).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (280).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1629).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (932).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1089).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (164).jpg (deflated 23%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (69).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1451).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1531).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (147).jpg (deflated 23%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1313).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (951).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1081).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (660).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1100).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1466).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1085).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1590).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1423).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1467).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1593).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1016).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (574).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1389).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (580).JPG (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (363).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (129).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (788).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1616).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1479).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1614).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1107).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1338).jpg (stored 0%)
# updating: content/MachineLearning/Dataset/ArASL_Database_54K_Final/ra/RA (1432).jpg (stored 0%)

# %%
import os
import random
import shutil

# define the directory containing the images
original_dir = '/content/MachineLearning/Dataset/SignLanguage_filtered'

# define the directories for the training and test sets
train_val_dir = '/content/MachineLearning/Dataset/train_val_set'
test_dir = '/content/MachineLearning/Dataset/test_set'

# create the training and test directories
os.makedirs(train_val_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# define the size of the test set
test_size = 0.2

# loop through the subdirectories in the original directory and copy the files to the train or test directories
for sub_dir in os.listdir(original_dir):
    sub_dir_path = os.path.join(original_dir, sub_dir)
    if not os.path.isdir(sub_dir_path):
        continue
    print(f'Processing {sub_dir_path}...')
    files = os.listdir(sub_dir_path)
    random.shuffle(files)
    num_files = len(files)
    num_test = int(test_size * num_files)
    #num_train = num_files - num_test
    train_files = files[num_test:]
    test_files = files[:num_test]
    for filename in train_files:
        src = os.path.join(sub_dir_path, filename)
        dst = os.path.join(train_val_dir, sub_dir, filename)
        os.makedirs(os.path.dirname(dst), exist_ok=True)
        shutil.copy(src, dst)
    for filename in test_files:
        src = os.path.join(sub_dir_path, filename)
        dst = os.path.join(test_dir, sub_dir, filename)
        os.makedirs(os.path.dirname(dst), exist_ok=True)
        shutil.copy(src, dst)
# Out:
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/al...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/khaa...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/sheen...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/zay...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/nun...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/la...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/ain...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/ha...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/kaaf...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/bb...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/haa...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/thal...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/ghain...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/seen...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/toot...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/yaa...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/thaa...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/aleff...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/taa...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/waw...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/laam...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/dhad...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/dal...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/ta...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/saad...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/dha...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/ya...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/fa...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/meem...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/jeem...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/gaaf...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/ra...

# %%
#!zip -r /content/MachineLearning/Dataset/test_set.zip /content/MachineLearning/Dataset/test_set
# --> GitHub
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1416).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (513).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (238).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1281).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (188).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1136).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1245).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1576).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (815).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1568).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (144).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1366).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1475).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (181).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (897).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1419).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (520).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (265).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1039).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1215).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (850).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1312).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1381).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1499).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (645).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (717).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (956).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1212).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1241).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (996).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (140).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (953).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (644).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (633).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1255).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (628).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (543).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (821).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1261).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1433).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (997).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1431).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (252).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1213).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (523).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1391).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (502).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (106).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1406).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (683).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1022).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (603).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (53).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1535).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (636).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (950).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (167).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1408).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (132).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1122).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1077).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1544).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (11).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (893).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (948).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1464).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1013).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (927).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (237).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (617).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1413).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (630).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1438).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (46).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (800).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1476).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (251).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (113).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (621).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (833).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (550).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1218).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (626).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (65).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (609).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (612).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1043).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (156).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (765).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (267).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (903).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1253).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (239).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (934).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (796).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (95).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (922).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (595).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (35).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (682).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (75).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (991).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1313).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1325).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1567).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1441).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (677).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1417).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1330).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (281).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (264).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1554).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1066).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (134).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (85).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (282).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (124).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1562).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1301).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (208).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (9).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1307).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (557).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1547).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (558).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1565).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1460).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (801).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (179).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1394).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (587).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1087).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1402).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (780).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (584).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (161).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1411).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (711).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1321).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1319).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (643).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (684).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1506).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/thal/THAL (1538).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/ (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1793).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (880).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1539).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1213).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1629).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1575).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (378).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1789).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1225).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (262).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (295).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1907).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1338).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1196).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (96).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (461).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1101).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1450).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1324).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (493).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (457).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (87).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1114).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1121).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1599).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1463).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (551).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (154).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (319).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (542).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1061).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1075).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1107).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (344).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (133).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (152).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1083).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1884).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1453).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (198).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1116).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (568).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1074).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1762).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (372).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (167).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1197).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (30).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (380).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1870).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (271).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1340).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1966).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1043).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1478).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1667).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1486).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (637).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1212).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1731).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1090).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1561).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1092).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (415).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1165).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1433).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1356).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (552).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (516).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1421).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1066).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1671).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (272).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (25).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (477).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (70).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (73).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1664).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1222).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1874).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1317).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1410).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1364).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1368).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (690).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1869).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1402).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (275).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1199).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1089).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (350).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (809).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (278).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (412).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (5).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (556).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1682).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1444).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1746).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1415).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1702).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (290).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (12).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (806).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (384).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1375).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1875).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1751).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (228).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1707).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1275).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (771).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (798).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1534).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1844).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1127).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1130).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (559).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1627).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (44).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1633).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1586).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1853).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (448).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (456).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (242).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1840).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1778).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1620).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (817).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (773).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1140).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (159).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1409).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (561).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1873).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1955).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (47).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (652).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (282).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (323).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (250).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (716).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1271).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (92).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (71).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1861).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (287).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1158).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1321).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1305).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1567).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1767).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1462).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1273).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (78).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (411).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1147).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1226).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1053).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (460).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1230).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (523).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (527).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1563).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1065).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (24).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1485).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1817).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1135).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1082).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (64).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1139).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1801).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1378).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (57).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (199).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (495).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (659).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (147).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (681).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (401).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (567).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (563).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (243).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1396).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (348).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (394).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1954).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1429).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (459).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (446).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1903).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1838).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1959).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1669).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (807).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (661).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1668).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1398).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1432).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1133).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1644).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1473).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1234).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1406).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1821).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (553).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (640).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1258).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1203).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1469).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1729).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (129).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1393).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1468).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (526).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (529).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1337).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1928).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1420).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (409).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1098).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (38).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (172).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1381).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1849).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (471).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (419).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (484).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1094).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1081).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1944).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (155).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (285).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (752).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (347).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (266).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (566).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (797).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1911).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (304).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1427).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (502).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (273).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1761).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (206).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (6).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (761).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1765).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1544).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (492).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1587).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1322).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (176).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1936).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1180).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1419).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1787).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (650).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1055).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (538).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1380).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1046).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1914).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (264).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1170).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1577).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1464).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (575).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1710).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1800).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1533).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (229).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1377).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1069).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1172).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1699).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1153).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (107).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (408).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1231).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (410).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (796).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1344).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (234).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1104).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1797).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1050).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1357).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1623).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (585).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (358).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1126).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1454).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (400).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1392).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (402).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1715).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1479).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1263).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1626).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (377).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1724).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1857).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (360).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1470).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (289).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1416).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1293).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1550).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ghain/GHAIN (1781).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/ (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1393).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1242).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1603).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (147).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (865).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (148).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (78).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (29).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (133).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (937).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (593).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (942).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1243).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1140).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (589).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (132).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1261).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1636).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1292).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (626).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (922).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1347).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (584).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1311).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (912).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1087).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (884).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (128).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1631).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1285).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (48).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1080).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (39).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (991).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (930).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1257).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (784).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1118).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1241).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (213).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (30).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (926).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1426).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1368).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1619).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1353).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (978).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (818).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (889).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1453).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1429).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (3).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1268).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (92).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (831).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (136).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (887).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (619).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (843).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (22).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (590).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (878).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (50).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (10).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (636).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (836).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (872).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1394).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (709).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (612).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (707).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1637).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (819).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1128).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (631).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (796).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (118).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1134).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (911).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (934).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (637).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (645).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1598).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (609).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (849).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (150).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1370).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (9).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1248).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (111).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (167).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (894).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1252).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (587).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1147).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1137).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (598).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (121).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (179).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1343).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (185).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1440).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (35).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1240).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1260).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (130).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (829).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (1450).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/seen/SEEN (158).jpg (stored 0%)
# ...
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (736).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1110).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (294).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (786).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1159).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1419).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1647).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (250).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (562).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1406).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (131).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (792).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1145).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (679).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1047).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (182).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (295).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1210).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (845).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (646).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (642).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1635).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1209).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (763).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (914).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (130).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (760).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1420).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1271).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1118).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (124).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1640).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1238).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1240).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1044).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (988).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (299).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (12).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1609).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (3).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (132).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1259).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (51).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1249).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1028).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (29).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (747).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1185).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (902).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (690).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1221).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (921).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1522).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (818).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (171).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (146).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (695).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (165).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1402).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1034).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (87).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (109).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (787).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1123).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (781).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (104).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (40).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (720).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (103).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (139).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (698).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (971).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1352).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1179).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (222).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (637).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1333).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (827).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (968).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (178).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (270).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1082).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (59).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (927).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (265).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (220).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (746).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1095).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1101).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1268).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (255).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (611).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1063).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1248).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (622).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1158).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1602).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (600).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (992).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (980).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (5).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (664).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (570).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1156).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (918).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (21).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (920).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (92).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1619).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (4).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (797).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1111).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (644).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (196).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (648).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1293).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1622).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1263).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (282).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (157).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (607).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (757).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1497).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (879).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (143).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (739).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1106).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (288).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1510).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1290).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (779).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (735).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1113).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (602).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1346).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (24).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (831).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (846).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (778).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (330).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1632).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (676).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (963).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (227).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1335).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (733).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (939).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1275).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1183).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1076).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (289).jpg (deflated 23%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1115).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (909).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (853).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1343).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1318).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1042).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (754).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1264).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (272).jpg (deflated 23%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1270).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (144).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (925).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1594).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1532).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1434).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1347).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (685).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1072).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (908).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1001).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (898).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1630).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (956).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1133).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (897).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (812).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1152).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1480).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1435).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (693).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1658).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (762).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (138).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1307).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1488).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1415).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (17).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (838).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1061).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (683).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (823).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (771).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1519).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (231).jpg (deflated 23%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (69).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1313).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1616).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1479).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1107).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/test_set/ra/RA (1338).jpg (stored 0%)

# %%
#!zip -r /content/MachineLearning/Dataset/train_val_set.zip /content/MachineLearning/Dataset/train_val_set
# --> GitHub
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1217).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (448).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1487).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1682).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (16).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (668).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (260).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1571).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1122).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1855).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (605).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1276).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1053).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (13).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (427).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (944).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1479).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1361).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1109).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (371).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1952).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1715).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1859).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1519).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1713).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1736).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1684).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (920).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1118).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1306).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1628).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1111).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (972).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1256).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1501).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (376).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (845).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (150).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (890).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1895).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1601).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1600).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (185).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (896).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1624).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (184).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (67).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1238).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (288).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (158).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (114).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (513).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1533).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1553).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1452).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1743).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (372).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1927).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (637).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1617).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (997).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (878).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (36).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1844).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1638).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1517).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1446).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (265).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (897).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (928).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (876).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1223).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1913).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1865).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (938).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (112).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1955).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (961).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (512).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1093).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (238).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (416).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (884).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1668).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1240).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1451).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1514).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (53).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1572).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (41).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (900).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (545).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1251).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1544).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1683).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (970).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (804).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1503).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1087).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1655).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (127).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (905).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1431).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1700).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (482).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (911).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (125).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1180).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (283).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1896).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1077).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1559).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (536).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1437).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1073).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1940).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1681).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (588).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (524).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1235).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1229).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1708).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1012).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1379).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1930).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1741).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1739).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (593).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1370).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1303).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (992).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1909).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1694).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (218).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1184).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (485).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1932).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1925).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (235).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (891).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (29).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1873).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1672).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1103).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1064).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1296).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (941).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (38).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1449).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (255).jpg (deflated 23%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1717).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1835).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (278).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (138).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (214).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (45).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (210).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (378).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (477).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (97).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (102).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (246).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1011).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (532).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1018).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (877).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (86).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (533).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (207).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1414).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1063).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (963).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1267).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (196).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (273).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1462).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1912).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1327).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (421).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1366).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (465).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (111).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (367).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (154).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (190).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (631).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1953).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (57).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1166).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1664).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (221).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (537).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (264).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (412).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (136).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1665).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (370).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (620).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1281).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1405).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (419).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (574).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (438).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (256).jpg (deflated 23%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (23).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1410).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1485).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (986).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1332).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1014).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (960).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1275).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (368).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1326).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (606).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1433).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (11).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1609).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1515).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1061).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1291).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (476).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1264).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (85).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1550).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1095).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (3).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1868).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (977).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (484).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (583).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1334).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (939).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1478).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (227).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1374).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1525).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1906).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1612).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1654).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (618).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1028).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1677).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (129).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (142).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (234).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1853).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (936).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (156).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1043).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1704).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1458).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1293).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (499).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1861).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1629).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (444).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1381).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (872).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1529).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1854).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1429).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (410).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1494).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (943).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1069).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (103).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1114).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1387).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1481).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (425).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1270).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (492).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (870).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (892).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1404).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1399).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1660).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (277).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1026).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1468).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (179).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (881).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (60).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (544).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1538).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1412).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (904).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1691).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1183).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (899).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1367).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1690).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1662).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (375).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (161).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1460).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (244).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1227).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1146).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (15).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (505).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1642).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (579).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1742).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1176).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1333).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (523).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1703).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (75).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1471).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (483).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1157).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (981).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (55).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1687).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1147).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1461).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (964).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1498).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (131).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (898).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1262).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1031).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1686).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1490).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1486).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (164).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1863).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (59).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (534).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (611).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1152).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1041).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (269).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1557).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (77).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1849).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1355).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (527).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1010).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1083).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1524).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (982).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (540).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1250).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1013).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1634).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1510).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1643).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1195).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (489).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1297).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1365).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (945).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1857).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1411).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (100).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (166).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1508).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1178).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (989).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1154).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (224).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1117).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1875).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (954).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1126).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1168).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1881).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (429).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (874).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1604).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1631).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (424).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (580).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1465).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (491).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1833).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (68).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1448).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1702).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1453).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1158).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (880).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1567).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (952).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1500).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (17).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (228).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1554).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (176).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1376).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1676).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (263).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1650).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1082).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1049).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (572).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (70).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (232).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1915).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1257).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1845).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (65).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (169).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1885).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (969).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1670).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1718).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1282).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1241).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1424).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (886).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (34).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1269).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (406).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (619).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1467).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1630).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1003).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1949).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (160).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (985).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (968).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (124).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (373).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (451).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1645).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1033).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (121).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (220).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (83).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (535).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (958).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1871).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1941).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1526).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (937).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1884).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1512).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (78).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1383).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (167).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1226).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1685).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1850).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (93).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (151).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (204).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (362).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1396).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (30).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1436).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1842).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (922).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1838).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1605).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (171).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (279).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1130).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1666).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1618).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (177).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (496).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (987).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1289).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1891).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1022).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (950).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1415).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1386).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1129).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1136).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1006).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (101).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1598).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (627).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1441).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (199).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1738).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1222).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1249).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1834).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (575).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1295).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1626).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1072).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1009).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1368).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (549).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1016).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1899).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1273).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (460).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1169).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1299).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (487).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1709).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1847).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1502).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1570).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1098).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1697).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (614).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (875).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1197).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (450).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1099).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (153).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1714).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (600).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1568).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (87).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1382).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1401).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1907).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1551).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (47).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1520).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (495).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (474).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (518).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (202).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (949).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1856).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1116).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (8).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (442).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1085).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1352).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (254).jpg (deflated 23%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1937).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (478).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1866).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1656).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (247).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (415).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (951).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1310).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1015).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1339).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (44).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (962).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1390).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1534).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1172).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1548).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (543).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1057).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (80).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1357).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1325).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1391).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1068).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1127).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1902).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (274).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1364).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1346).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (929).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1710).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (959).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (91).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (598).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (506).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/fa/FA (1060).jpg (stored 0%)
# ...
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (930).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1334).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1503).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (228).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1149).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (995).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1628).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (756).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (843).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (737).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1172).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (671).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1161).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (806).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1120).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (200).jpg (deflated 23%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (117).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (816).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (744).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (341).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1363).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (72).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1020).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (110).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1056).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (173).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1285).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1411).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1131).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1039).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (249).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (614).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (668).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1242).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (888).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (894).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (625).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1092).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1473).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (839).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (238).jpg (deflated 23%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (576).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (837).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1232).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (651).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (936).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (800).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1430).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (149).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (814).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (233).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1036).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (658).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (327).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (259).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1605).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (665).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (965).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (638).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1431).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (273).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (985).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1405).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (703).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1068).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1009).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1234).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1195).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (946).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1173).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1426).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1457).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1490).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (900).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1591).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (635).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1053).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (706).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (677).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (672).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (71).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (247).jpg (deflated 23%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (725).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (889).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (712).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1483).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1611).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (624).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (239).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1225).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1336).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (31).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1513).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1142).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (166).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (353).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (277).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (850).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (929).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1359).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1482).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1150).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (335).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (857).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (260).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (64).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (719).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (799).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1012).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1499).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (42).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1078).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (37).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1261).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (822).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1311).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1069).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1266).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1098).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1129).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1646).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (982).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (617).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (935).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1627).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (769).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (235).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (188).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (700).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1337).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (923).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (777).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1241).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1470).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1325).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1250).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (169).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (820).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (26).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1117).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (715).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (340).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (662).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (66).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (36).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (287).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1066).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (632).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (934).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1514).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (100).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1144).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (248).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1000).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1596).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1452).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (970).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (734).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (790).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (578).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (990).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (55).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (280).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1629).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (932).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1089).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (164).jpg (deflated 23%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1451).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1531).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (147).jpg (deflated 23%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (951).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1081).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (660).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1100).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1466).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1085).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1590).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1423).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1467).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1593).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1016).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (574).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1389).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (580).JPG (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (363).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (129).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (788).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1614).jpg (stored 0%)
#   adding: content/MachineLearning/Dataset/train_val_set/ra/RA (1432).jpg (stored 0%)

# %%
def get_num_instances(folder):
     #get the number of instances in each folder
     num_instances = [len(os.listdir(folder + '/' + i)) for i in os.listdir(folder)]
     #return the number of instances
     return num_instances

# %%
train_val_list = get_num_instances('/content/MachineLearning/Dataset/train_val_set')
sum = 0
for i in train_val_list:
  sum += i 
print(sum)
# Out:
# 30930

# %%
test_list = get_num_instances('/content/MachineLearning/Dataset/test_set')
sum = 0
for i in test_list:
  sum += i 
print(sum)
# Out:
# 7715

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

path = "/content/MachineLearning/Dataset/train_val_set"

#create imagegenerator and load images, taking some images to create validation and training dataset
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, 
                                                                  validation_split=0.25, 
                                                                  rotation_range=10, 
                                                                  width_shift_range=0.1, 
                                                                  height_shift_range=0.1, 
                                                                  zoom_range=0.1, 
                                                                  horizontal_flip=True)

#create training dataset
train_generator = image_generator.flow_from_directory(
    path,
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical',
    subset='training') # set as training data
#create validation dataset
validation_generator = image_generator.flow_from_directory(
    path, # same directory as training data
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical',
    subset='validation') # set as validation data

#define the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(64, 64, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(32, activation='softmax')
])

# compile the model
model.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# train the model
history = model.fit_generator(
    train_generator,
    steps_per_epoch=100,
    epochs=10)
# Out:
# Found 23210 images belonging to 32 classes.
# Found 7720 images belonging to 32 classes.
# <ipython-input-1-6839253cfc2d>:56: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/10
# 100/100 [==============================] - 32s 289ms/step - loss: 3.4569 - accuracy: 0.0362
# Epoch 2/10
# 100/100 [==============================] - 19s 193ms/step - loss: 3.3117 - accuracy: 0.0739
# Epoch 3/10
# 100/100 [==============================] - 20s 200ms/step - loss: 2.8486 - accuracy: 0.1784
# Epoch 4/10
# 100/100 [==============================] - 19s 193ms/step - loss: 2.2610 - accuracy: 0.3219
# Epoch 5/10
# 100/100 [==============================] - 22s 219ms/step - loss: 1.9055 - accuracy: 0.4253
# Epoch 6/10
# 100/100 [==============================] - 20s 197ms/step - loss: 1.6719 - accuracy: 0.4856
# Epoch 7/10
# 100/100 [==============================] - 21s 206ms/step - loss: 1.5056 - accuracy: 0.5328
# Epoch 8/10
# 100/100 [==============================] - 19s 191ms/step - loss: 1.4253 - accuracy: 0.5519
# Epoch 9/10
# 100/100 [==============================] - 21s 208ms/step - loss: 1.2563 - accuracy: 0.5959
# Epoch 10/10
# 100/100 [==============================] - 19s 193ms/step - loss: 1.1408 - accuracy: 0.6334
