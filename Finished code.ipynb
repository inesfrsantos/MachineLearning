# %% [markdown]
# <a href="https://colab.research.google.com/github/inesfrsantos/MachineLearning/blob/main/Finished%20code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Analysis and Preprocessing

# %%
## Load needed packages and Data
import pandas as pd
import os
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import hashlib
import time
import psutil
import os
import random
import shutil
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from tqdm import tqdm 
from sklearn.metrics import classification_report
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler
from sklearn.metrics import confusion_matrix
from tensorflow.keras import layers
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
# Data is stored in a GitHub Repository
# !git clone https://github.com/inesfrsantos/MachineLearning.git
# Out:
# fatal: destination path 'MachineLearning' already exists and is not an empty directory.

# %%
# !ls
# Out:
# MachineLearning  sample_data

# %%
path = "/content/MachineLearning/Dataset/ArASL_Database_54K_Final"

# %%
# create empty lists to store image file paths, images, and labels
img_path = []
images = []
labels = []

# loop through each folder in the path
for folder_name in os.listdir(path):
    # create the full path to the folder
    folder_path = os.path.join(path, folder_name)
    # skip any non-directory files
    if not os.path.isdir(folder_path):
        continue
    # loop through each file in the folder
    for file_name in os.listdir(folder_path):
        # check if the file is a jpg, png, JPG, or PNG file
        if file_name.endswith(".jpg") or file_name.endswith(".png") or file_name.endswith(".JPG") or file_name.endswith(".PNG"):
            # create the full path to the image file
            image_path = os.path.join(folder_path, file_name)
            # check if the file is a regular file
            if os.path.isfile(image_path):
                # open the image file and convert it to grayscale
                image = Image.open(image_path).convert('L')
                # append the image file path, image, and label to their respective lists
                images.append(image)
                labels.append(folder_name)
                img_path.append(image_path)

# create a pandas dataframe with the image file paths, images, and labels as columns
df = pd.DataFrame({'img_path': img_path, 'image': images, 'label': labels})

# %% [markdown]
# ## Exploratory Analysis

# %%
#get the total number of pictures in the dataset
num_pics = len(df)
print("Number of pictures in the dataset:\n")
print(num_pics, "\n")

#get the total number of pictures per category and the corresponding percentage
label_counts = df['label'].value_counts()
print("Number and Percentage of pictures per Label:\n")
for label, count in label_counts.items():
    percentage = count/num_pics * 100
    print(f"{label}: {count} ({percentage:.2f}%)")
# Out:
# Number of pictures in the dataset:
#
# 38645
#
# Number and Percentage of pictures per Label:
#
# ain: 1771 (4.58%)
# ghain: 1564 (4.05%)
# fa: 1464 (3.79%)
# ta: 1421 (3.68%)
# nun: 1342 (3.47%)
# dha: 1330 (3.44%)
# laam: 1326 (3.43%)
# ra: 1321 (3.42%)
# bb: 1311 (3.39%)
# dal: 1308 (3.38%)
# gaaf: 1296 (3.35%)
# toot: 1281 (3.31%)
# meem: 1277 (3.30%)
# ha: 1274 (3.30%)
# saad: 1270 (3.29%)
# khaa: 1245 (3.22%)
# ya: 1228 (3.18%)
# haa: 1191 (3.08%)
# la: 1178 (3.05%)
# thal: 1177 (3.05%)
# taa: 1163 (3.01%)
# dhad: 1137 (2.94%)
# zay: 1108 (2.87%)
# thaa: 1108 (2.87%)
# jeem: 1108 (2.87%)
# yaa: 1063 (2.75%)
# kaaf: 1029 (2.66%)
# aleff: 1018 (2.63%)
# sheen: 898 (2.32%)
# al: 896 (2.32%)
# waw: 785 (2.03%)
# seen: 757 (1.96%)

# %%
# plot the count of images per Label
# Get unique labels from the dataframe
Label = df['label'].unique()

# Set the size of the plot
plt.figure(figsize=(16,4))

# Create a bar chart of label counts
plt.bar(range(len(label_counts)), label_counts, alpha = .7)

# Set x-axis tick marks and labels to the unique labels
plt.xticks(range(len(label_counts)), Label, rotation = 45)

# Set x and y axis labels
plt.xlabel("Label")
plt.ylabel("Amount")

# Display the plot
plt.show()

# %%
# Plot Examples of all signs with theri best quality
# Get one image for each label
label_to_image = {}
for label in df['label'].unique():
    label_df = df[df['label'] == label]
    variances = [np.var(np.array(image)) for image in label_df['image']]
    max_idx = np.argmax(variances)
    label_to_image[label] = label_df.iloc[max_idx]['image']

# Create a figure with subplots
fig, axs = plt.subplots(nrows=int(np.ceil(len(label_to_image) / 8)), ncols=8, figsize=(32, 12))

# Loop over each label and plot the corresponding image
for i, (label, image) in enumerate(label_to_image.items()):
    row = i // 8
    col = i % 8
    axs[row, col].imshow(image, cmap='gray')
    axs[row, col].set_title(label, fontsize=20)
    axs[row, col].axis('off')

# Adjust spacing and display the plot
fig.tight_layout()
plt.show()

# %%
# plot the square root size vs aspect ratio to see the distribution of sizes
# first calculate the square root size and the aspect ratio
square_root_size = []
aspect_ratio = []
for image in df['image']:
  #size of the images in pixels
  width, height = image.size
  
  #calculate the square root size
  sqrt_size = (width * height) ** 0.5
  square_root_size.append(sqrt_size)

  #cxalculate the aspect_ration
  aspt_rt = width/height
  aspect_ratio.append(aspt_rt)

# plot the data
fig, ax = plt.subplots()
ax.scatter(aspect_ratio, square_root_size)

# add labels and a title
ax.set_xlabel("aspect ratio")
ax.set_ylabel("square root size")
ax.set_title("square root size vs. aspect ratio")

# show the plot
plt.show()

# %%
df['aspect_ratio'] = aspect_ratio
df['square_root_size'] = square_root_size

# %%
# Calculate the number of images with different aspect ratios than 1:1.
num_dif_ratio = len(np.where(df['aspect_ratio'] != 1)[0])
print(f"Number of different ratio: {num_dif_ratio}")
# Out:
# Number of different ratio: 10

# %%
#reduce the dataframe to the rows that have a different aspect ratio than 1
df_asp = df.loc[df['aspect_ratio'] != 1]

# Define the number of columns in the figure
num_cols = 5

# Calculate the number of rows needed
num_rows = len(df_asp) // num_cols

# Create a new figure
fig, axes = plt.subplots(num_rows, num_cols, figsize=(32, 12))

# Flatten the axes array for ease of iteration
axes = axes.flatten()

# Loop through each image in the DataFrame and display it
for i, (_, row) in enumerate(df_asp.iterrows()):
    img = row['image']
    ax = axes[i]
    ax.imshow(img, cmap='gray')
    ax.set_title(row['label'])
    ax.axis('off')
    
# Remove any unused axes
for i in range(len(df), num_rows * num_cols):
    axes[i].axis('off')
    
plt.tight_layout()
plt.show()

# %%
# Find rows where the image size is not (64,64)
non_6464_rows = df[df['image'].apply(lambda x: x.size) != (64,64)]

#get the total number of pictures that are not size (64,64)
num_pics_64 = len(non_6464_rows)
num_pics = len(df)
Perc_of_whole = num_pics_64/num_pics * 100
print("Number of pictures with different size:\n")
print(num_pics_64)
print("That is", f"{Perc_of_whole:.2f}%", "of the whole dataset \n")

#split the information per category
label_counts_64 = non_6464_rows['label'].value_counts()
label_counts = df['label'].value_counts()
print("Number and Percentage of different sized pictures per Label:")
print("(The Percentage refers to the number of all pictures of that label):\n")
for label, count in label_counts_64.items():
    percentage = count/label_counts[label] * 100
    print(f"{label}: {count} ({percentage:.2f}%)")
# Out:
# Number of pictures with different size:
#
# 33
# That is 0.09% of the whole dataset
#
# Number and Percentage of different sized pictures per Label:
# (The Percentage refers to the number of all pictures of that label):
#
# meem: 13 (1.02%)
# kaaf: 10 (0.97%)
# haa: 10 (0.84%)

# %%
# Color Channel Analysis
def get_channel_means(image):
    return np.mean(np.array(image))
# Initialize a list to store the mean pixel intensity of each color channel
channel_means = []

# Loop through the images in the dataset and calculate the channel means
for i in range(len(df)):
    image = df['image'][i]
    channel_means.append(get_channel_means(image))

# Convert the channel means to a numpy array and calculate the mean and standard deviation for the channel
channel_means = np.array(channel_means)
mean_intensity = np.mean(channel_means)
std_intensity = np.std(channel_means)

# Print the mean and standard deviation for the channel
print("Mean pixel intensity: {:.2f}".format(mean_intensity))
print("Standard deviation of pixel intensity: {:.2f}".format(std_intensity))
# Out:
# Mean pixel intensity: 181.31
# Standard deviation of pixel intensity: 28.93

# %% [markdown]
# ## Preprocessing

# %%
filtered_images = []

# %%
# Check for Duplicates

def get_hash(img_path):
    """
    Calculates the MD5 checksum of the input image.

    Args:
        img_path (str): The file path of the input image.

    Returns:
        str: The MD5 checksum of the image.
    """
    # Open the input image in binary mode
    with open(img_path, "rb") as f:
        # Initialize a new MD5 hash object
        img_hash = hashlib.md5()
        # Read the image data in chunks and update the hash object with each chunk
        while chunk := f.read(8192):
           img_hash.update(chunk)
    # Return the hexadecimal representation of the hash value
    return img_hash.hexdigest()

# %%
#Add a column to the DataFrame to store the hash values for each image in the dataset
df['hash'] = df['img_path'].apply(get_hash)

#Calculate the number of unique hash values in the dataset and identify duplicates based on the hash value
unique_values = df['hash'].nunique()
duplicates = df[df.duplicated(['hash'])]

#Print the number of duplicates found in the dataset
print("Duplicates in the Dataset based on the calculated hash value:")
print(len(duplicates), '\n')

#Print the total number of images in the dataset before dropping duplicates
print("Images in the Dataset before dropping Duplicates:")
print(len(df), '\n')

#Drop the duplicate images from the dataset based on the hash value and reset the index
df.drop_duplicates(subset=['hash'], inplace=True)
df = df.reset_index(drop=True)

#Print the total number of images in the dataset after dropping duplicates
print("Images in the Dataset after dropping Duplicates:")
print(len(df))

image_path = duplicates['img_path']
print(image_path)
for path in image_path:
  filtered_images.append(path)

print(len(filtered_images))
# Out:
# Duplicates in the Dataset based on the calculated hash value:
# 0
#
# Images in the Dataset before dropping Duplicates:
# 38645
#
# Images in the Dataset after dropping Duplicates:
# 38645
# Series([], Name: img_path, dtype: object)
# 0

# %%
# Create an empty list to store the anomaly scores for each image
anomaly_scores = []

# Loop through each image in the dataset
for i in range(len(df)):
    # Load the image
    image = df.loc[i, 'image']
    
    # Calculate the mean and standard deviation of the image
    mean = np.mean(image)
    std = np.std(image)
    
    # Calculate the anomaly score
    anomaly_score = np.abs((image - mean) / std).mean()
    anomaly_scores.append(anomaly_score)

# Add the anomaly scores as a new column to the dataframe
df['anomaly_score'] = anomaly_scores

# Print the dataframe sorted by anomaly score
print(df.sort_values(by='anomaly_score', ascending=False))
# Out:
#                                                 img_path  \
# 26445  /content/MachineLearning/Dataset/ArASL_Databas...
# 9212   /content/MachineLearning/Dataset/ArASL_Databas...
# 37545  /content/MachineLearning/Dataset/ArASL_Databas...
# 20422  /content/MachineLearning/Dataset/ArASL_Databas...
# 8240   /content/MachineLearning/Dataset/ArASL_Databas...
# ...                                                  ...
# 2318   /content/MachineLearning/Dataset/ArASL_Databas...
# 34913  /content/MachineLearning/Dataset/ArASL_Databas...
# 38042  /content/MachineLearning/Dataset/ArASL_Databas...
# 38246  /content/MachineLearning/Dataset/ArASL_Databas...
# 6772   /content/MachineLearning/Dataset/ArASL_Databas...
#
#                                                    image  label  aspect_ratio  \
# 26445  <PIL.Image.Image image mode=L size=64x64 at 0x...  ghain           1.0
# 9212   <PIL.Image.Image image mode=L size=64x64 at 0x...    dha           1.0
# 37545  <PIL.Image.Image image mode=L size=64x64 at 0x...    taa           1.0
# 20422  <PIL.Image.Image image mode=L size=64x64 at 0x...   laam           1.0
# 8240   <PIL.Image.Image image mode=L size=64x64 at 0x...    dha           1.0
# ...                                                  ...    ...           ...
# 2318   <PIL.Image.Image image mode=L size=64x64 at 0x...   meem           1.0
# 34913  <PIL.Image.Image image mode=L size=64x64 at 0x...    waw           1.0
# 38042  <PIL.Image.Image image mode=L size=64x64 at 0x...    taa           1.0
# 38246  <PIL.Image.Image image mode=L size=64x64 at 0x...    taa           1.0
# 6772   <PIL.Image.Image image mode=L size=64x64 at 0x...    dal           1.0
#
#        square_root_size                              hash  anomaly_score
# 26445              64.0  a8371eb309b5d6e213306f5e954fdc30       0.849997
# 9212               64.0  f467ebf7b53124fc8d81377abc8fbc9d       0.849997
# 37545              64.0  a3d80b8bd16bc8feacd035fa486b59bd       0.849993
# 20422              64.0  e60d9b831fe0496530e86f633b002524       0.849991
# 8240               64.0  899b72df71b297e9ca5233cca8599e97       0.849988
# ...                 ...                               ...            ...
# 2318               64.0  5c66354974afd5cb2daedc0a4ed2d73f       0.481937
# 34913              64.0  d16b91b1873051b3321f8da7bfe08ba4       0.475243
# 38042              64.0  b044cf9920e191d40f2a8eab4e763647       0.468129
# 38246              64.0  d182aaf6cddbda8a406a7534e66e2553       0.443558
# 6772               64.0  c65ff0291608e262755b32f0b82ddcf4       0.422069
#
# [38645 rows x 7 columns]

# %%
#Filter out images with anomaly scores above 0.85
anomal_img = df.loc[df['anomaly_score'] >= 0.85]
df_filtered = df.loc[df['anomaly_score'] < 0.85]

#Reset the index to start from 0
df_filtered = df_filtered.reset_index(drop=True)

#Print the number of images in the filtered dataset
print('Number of pictures in the dataset after filtering:')
print(len(df_filtered))

image_path = anomal_img['img_path']
for path in image_path:
  filtered_images.append(path)

print(len(filtered_images))
# Out:
# Number of pictures in the dataset after filtering:
# 38645
# 0

# %%
# filter the images from the train and test directories
for image_path in filtered_images:
  os.remove(image_path)

# %%
#!zip -r /content/MachineLearning/Dataset/filtered_Dataset.zip /content/MachineLearning/Dataset/ArASL_Database_54K_Final

# %%
# define the directory containing the images
original_dir = '/content/MachineLearning/Dataset/SignLanguage_filtered'

# define the directories for the training, validation, and test sets
train_dir = '/content/MachineLearning/Dataset/train_data'
val_dir = '/content/MachineLearning/Dataset/valid_data'
test_dir = '/content/MachineLearning/Dataset/test_data'

# create the directories for the training, validation, and test sets
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# define the size of the validation and test sets
val_size = 0.2
test_size = 0.2

# loop through the subdirectories in the original directory and copy the files to the train, validation, or test directories
for sub_dir in os.listdir(original_dir):
    sub_dir_path = os.path.join(original_dir, sub_dir)
    if not os.path.isdir(sub_dir_path):
        continue
    print(f'Processing {sub_dir_path}...')
    files = os.listdir(sub_dir_path)
    random.shuffle(files)
    num_files = len(files)
    num_val = int(val_size * num_files)
    num_test = int(test_size * num_files)
    num_train = num_files - num_val - num_test
    train_files = files[:num_train]
    val_files = files[num_train:num_train+num_val]
    test_files = files[num_train+num_val:]
    for filename in train_files:
        src = os.path.join(sub_dir_path, filename)
        dst = os.path.join(train_dir, sub_dir, filename)
        os.makedirs(os.path.dirname(dst), exist_ok=True)
        shutil.copy(src, dst)
    for filename in val_files:
        src = os.path.join(sub_dir_path, filename)
        dst = os.path.join(val_dir, sub_dir, filename)
        os.makedirs(os.path.dirname(dst), exist_ok=True)
        shutil.copy(src, dst)
    for filename in test_files:
        src = os.path.join(sub_dir_path, filename)
        dst = os.path.join(test_dir, sub_dir, filename)
        os.makedirs(os.path.dirname(dst), exist_ok=True)
        shutil.copy(src, dst)
# Out:
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/kaaf...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/al...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/meem...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/sheen...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/ya...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/ra...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/dal...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/dha...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/jeem...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/ha...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/khaa...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/seen...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/ain...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/yaa...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/thaa...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/toot...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/la...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/laam...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/zay...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/fa...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/dhad...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/ghain...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/saad...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/haa...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/aleff...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/ta...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/gaaf...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/nun...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/waw...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/thal...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/bb...
# Processing /content/MachineLearning/Dataset/SignLanguage_filtered/taa...

# %% [markdown]
# ## Data Augmentation on the training set

# %%
path = "/content/MachineLearning/Dataset/train_data"

# loop through the folders and augment images
for folder in os.listdir(path):
    print(folder)
    if folder == '.DS_Store':
        continue
    else:
        folder_path = os.path.join(path, folder)
        print(folder_path)
        for file in os.listdir(folder_path):
            if file == '.DS_Store':
                continue
            else:
                file_path = os.path.join(folder_path, file)
                print(file_path)
                image = tf.keras.preprocessing.image.load_img(file_path)
                image = tf.keras.preprocessing.image.img_to_array(image)
                image = np.expand_dims(image, axis=0)

                # Randomly select an augmentation operation
                operations = {
                    'rotation': random.choice([True, False]),
                    'width_shift': random.choice([True, False]),
                    'height_shift': random.choice([True, False]),
                    'shear': random.choice([True, False]),
                    'zoom': random.choice([True, False]),
                    'horizontal_flip': random.choice([True, False])
                }

                # Apply selected augmentation operation
                if operations['rotation']:
                    rotation_range = random.randint(1, 30)
                else:
                    rotation_range = 0

                if operations['width_shift']:
                    width_shift_range = random.uniform(0.1, 0.2)
                else:
                    width_shift_range = 0.0

                if operations['height_shift']:
                    height_shift_range = random.uniform(0.1, 0.2)
                else:
                    height_shift_range = 0.0

                if operations['shear']:
                    shear_range = random.uniform(0.1, 0.2)
                else:
                    shear_range = 0.0

                if operations['zoom']:
                    zoom_range = random.uniform(0.1, 0.2)
                else:
                    zoom_range = 0.0

                if operations['horizontal_flip']:
                    horizontal_flip = True
                else:
                    horizontal_flip = False

                image_generator = tf.keras.preprocessing.image.ImageDataGenerator(
                    rotation_range=rotation_range,
                    width_shift_range=width_shift_range,
                    height_shift_range=height_shift_range,
                    shear_range=shear_range,
                    zoom_range=zoom_range,
                    horizontal_flip=horizontal_flip,
                    fill_mode='nearest'
                )

                augmented_image_iterator = image_generator.flow(image, batch_size=1)
                augmented_image = next(augmented_image_iterator)
                augmented_image = augmented_image[0].astype('uint8')
                augmented_image = tf.keras.preprocessing.image.array_to_img(augmented_image)
                filename, extension = os.path.splitext(file)
                new_filename = filename + '_aug' + extension
                new_file_path = os.path.join(folder_path, new_filename)
                augmented_image.save(new_file_path)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/MachineLearning/Dataset/train_data/bb/BB (1365).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (705)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1467)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (108)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (368).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (313).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1539).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (518)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (103)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (288)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (203)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1530)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1101).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1015)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (385)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (403)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (699).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1617)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1453).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (945)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (173)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (118)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1353)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (190)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1130).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (717).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (238)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (252).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (449).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1062)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (253)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (593).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (225)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (83)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1654)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1249).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1612)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1281)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1355)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (939)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1029)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1440)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (938)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (239)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1019)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1505).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1456).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (723)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1746).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1545)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1037).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (402)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (542)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (222)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1744).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1336).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1689)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1744)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (811).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1297)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (347)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1556).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1243)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1661)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (397).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1222)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1776)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1770)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1018).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1548).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1056)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (601)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1508).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1584).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (48).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (289).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (12).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1084).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1034)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1677)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (922)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1290)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (335)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1332).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1773)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1566)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1137)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1341).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1557).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1502)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1299)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1693)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1607).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1575).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1251).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (531)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (693).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (136).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (208)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1582).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (542)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1629)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (43).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1438)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (146).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (710)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (355)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (971)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (258).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1480)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (137)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (306)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (318)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1653)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (130)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1750).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (446).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1614)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (361).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (100)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (707)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (913).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1455)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (498)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1393)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (147)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1326).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1638).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (511)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1330).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (489).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (594)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (108).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (979).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1723)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1576).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1690)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1768)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (342).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1658)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1137)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1431)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (587).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (194)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (186).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1590).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1014)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (992)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1323)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (323).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (738)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1586)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1768).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (486).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (79)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1466).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1554)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (248)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (540).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (715)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1552)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (228).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (989)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1132).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1638)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1548)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1041)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1696).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (249)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1303)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1571)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1016)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1644)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (40)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (962)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1285)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1027).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1030)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (484)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (290).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1361).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (130)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1143).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (936)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1472).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (142)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1035)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (174).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1637)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1363)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (311).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (265).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1133).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (27).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (506)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (240)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (153)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1042)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (140).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1745)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (944).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1718)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1221).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1302).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (949)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (484).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (716)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1289).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1585).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1666).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (22).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1746)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1521).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (637).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (629)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (88).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (545).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1144)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1656)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1293).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (439).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1731).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (721).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (640)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (622)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (417)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1022)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1108)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (252)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1113)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (11)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1556)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (371)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (109).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1772).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (302).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (323)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (229).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (35)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1155)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (736)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1433).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1507).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1001).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1354).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (165).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1663).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1014).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (236).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (537)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (33).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1091)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1594)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (398)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1322).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1680)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1470)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (532)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (713).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1646)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1730)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1367)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1058)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1018)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (339)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1632)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (716).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (176).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (522).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1633).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1511)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (488).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1335)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1354)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (214).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1398).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (131).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1759)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (523)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (610).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (113).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (14)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1718).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (249).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (145)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1733).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (487)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1676)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1146).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1079)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (384).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1041).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (630)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (362)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (73).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (955)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1101)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (150).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1762)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (721)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1350)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1044).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1565).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1626)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1457)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1363)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1603)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1512)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (722)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (107)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (612)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (414).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (354)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (121).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (319).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1611)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1153)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (336)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1315).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (634)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1677).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (355)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1490).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1764).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1496).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1499)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1760)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1063)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (618)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1663)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (522)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (486)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (110)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (345)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (58)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1306).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1695).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1239)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (698)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1507)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1550)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (93)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1461).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1560)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (244).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (522)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (416).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (693)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (968)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1526)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1312).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (381)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (70)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1312)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (297)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1577).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (450).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (111)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1321).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (5).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (82)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (249)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (534)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (732).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (383).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (271)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (630).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1651).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1011)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1666)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (260).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (362)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1314)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1087)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1154).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1118).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (869)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1486).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (606).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (961).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (129).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1332)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (47).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (682).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1589)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (617)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1368)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1456)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1295).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (436)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (381).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1016).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (640)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1536).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (922)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (273).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1089)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1250)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (991)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (125).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1388)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (314)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1149)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (18)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1359)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1779)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (377).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (13).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1518).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (55)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1531)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1784).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1539)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (484)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1554)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1484).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1249)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (601).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1065)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1771).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (15)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1097)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1131).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1342)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (978)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1571).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (634).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (506)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1104)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1658).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (310)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1106)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1039).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (330).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1280).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (227)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1320).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1223)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1724).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1634).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (272).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1091).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1002)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (220)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (498).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (135)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (48)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (697)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1008).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1683).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1594)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1098)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1563)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (8).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (32).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (182).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1309).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (971).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (417).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (603)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (313)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1003)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (120)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (358)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1103).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (172)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (727).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (72).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (248).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (980)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (181).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (231)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1775).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (149)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1766).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (145)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1305)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1432)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1451).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1040).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (704)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1537)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1340).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (922).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1338)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (101)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (953)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1122).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (193).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (68).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (103).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (756)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (625).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1662)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1600).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (310).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (623)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (731)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1644)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1595).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (435)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1542)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1302)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (491)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1308).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (210)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1459)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (586)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1026)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1412).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1553)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1508)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (49).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1570)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1765)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (295).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (945).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (702).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (177)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (413).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1353)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (211).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1628).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (495)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1117)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1687).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (394).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (176)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1031).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1585)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1074).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1148)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1447)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1003)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (150)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1051).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (186)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1224)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (120).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (411)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (296)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1043).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (529).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1054)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (620)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (970)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (594)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1109).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1403)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (401).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1329)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1531)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1672)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (88)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (117).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (923).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1351).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1571)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1663)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1525)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1300)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (451)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (144)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1083).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (411)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1314)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1745).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1670).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (380)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1588).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1532).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (497)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (713)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1591)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (179).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (695)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (26)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (409)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (205).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (85).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (728)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (989).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (993).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1289)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1334)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1339)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1151)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (380).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (261).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (530)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1018)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (371).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1344)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1637)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1637).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1695)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1300).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1135)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1069)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (374)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (115)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (709).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (41)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1492)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (75).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (532).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (961)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (520).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (699)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (105)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1734)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (628).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (526)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (402)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (937).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (213)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1521)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1407)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (317)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1515)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (152)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1570)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1691).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1467).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1239).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1155).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (274)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1450)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1051)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1062)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1124)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (202)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1622)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1559)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1775)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1050)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1000)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (93).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (226)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1528).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (108)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (518).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1049)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (635)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (136)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1301).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (533).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (161).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1294)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (499)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1083)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (730)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1244)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1125)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1026)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (708).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (26).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1153)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (942)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1006).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1000)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1781)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1304)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1551)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1155)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1542).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1338).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (111).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (397)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (633).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1224).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1567).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (322)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (497)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (208).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1629).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (446)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (283)_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1521)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1460)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1697).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1072)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1751)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (375)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1396).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (519)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (366).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1523)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1657)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1032)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (635)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1397)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1719).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (700).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (515)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1764)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (60).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1074)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1325)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1682)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1560).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (448)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1249)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (442).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (436).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1076)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (25).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1050)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1298)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1059)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (514)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1456)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (620)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1053)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1739)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1334).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1485)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (447).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (87)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (501).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1140)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1752)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1557)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (719)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1756).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1025)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (210).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (401)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (12)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1537).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (239)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1524)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (82).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (163).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1328).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (95)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (303)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (1530)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1681).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (30).JPG
# /content/MachineLearning/Dataset/train_data/bb/BB (503)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (116).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1699)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1492).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1468)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1020).jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1144)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1313)_aug.jpg
# /content/MachineLearning/Dataset/train_data/bb/BB (1636).jpg
# ...
# /content/MachineLearning/Dataset/train_data/taa/TAA (290)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (898)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1137)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1357).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (839).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1639).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1099).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (765).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1103).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (987)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1489)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1111)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1145).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (941).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1362).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (928)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (908).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1516)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1325)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1678)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1609)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (763)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1602)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1082)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1408)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1592)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (919)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1339).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (837).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (29).JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (74)_aug.JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (241)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1027).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1359)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (812)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1385)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1474).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1043).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1526)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1374)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1053).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1751).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1398)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (897).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (79)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (732)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1814)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1163)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1629).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1063).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1412).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1094)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (27)_aug.JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (1697).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1030).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1148).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1582)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (104).JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (1589).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (832)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1783)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1457)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1782).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1383).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1693)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (885).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (10)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (61)_aug.JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (987).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (686)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (1692)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (380)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1094).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (582).JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (762).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1396).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1062)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (327)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1382)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1071)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (768).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (383).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (960).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (126).JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (1398)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (770)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1079)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1485)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1664).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (939).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1817).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1705)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (230).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1818).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1534).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1707)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (889)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (333)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (821)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1411)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1757)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1119).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1603).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1175).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1407).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1711)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (393).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1096).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (774)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1618)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1759).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (241)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1453).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1675)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (84).JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (779)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (526).JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (378)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1721).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (379)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1143).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1074).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1424)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (28).JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (113)_aug.JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (117)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (738)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1560)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (325)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1749)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1106).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (132)_aug.JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (1054)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (743)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1464)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (872)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1136)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1346).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1).JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (789)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1468)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1076)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1477)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (847).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1143)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (71).JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (1578)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (791)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1365).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1690)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1532).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1385)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1358).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1513)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1522)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1030)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (951).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1604)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1340).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1157).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (308).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1712)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (707)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (802).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1503)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (785).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (896)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (113).JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (1377).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (734)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (948)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1020)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (68).JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (88)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (1133).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (896)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1782)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1571).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1061)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (898).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (915)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (699).JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (1117)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (265).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (326).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (110).JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (1653).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (935)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (867)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (874)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (939)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1400)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (855)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1532)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (80)_aug_aug.JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (1690).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (45).JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (1365)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1408).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (10)_aug.JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (1086)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1485).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1456)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1539).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1132)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (87)_aug.JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (1323)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1528).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1356)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (329)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (10).JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (777)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (685)_aug.JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (1104).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1474)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (79).JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (1378).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (775)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1344)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (493)_aug.JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (240).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (47).JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (99).JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (270)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1391)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1527).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (245).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (105).JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (727).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (699)_aug.JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (121)_aug.JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (1388)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (108)_aug.JPG
# /content/MachineLearning/Dataset/train_data/taa/TAA (370).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1741)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1721)_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1391).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1601)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1724).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (267).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (1642)_aug_aug.jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (325).jpg
# /content/MachineLearning/Dataset/train_data/taa/TAA (390).jpg

# %%
original_images = []
augmented_images = []

# Loop through the folders and collect original and augmented images
for folder in os.listdir(path):
    if folder == '.DS_Store':
        continue
    else:
        folder_path = os.path.join(path, folder)
        for file in os.listdir(folder_path):
            if file == '.DS_Store':
                continue
            else:
                file_path = os.path.join(folder_path, file)
                if "_aug" in file:
                    augmented_images.append(file_path)
                else:
                    original_images.append(file_path)

# Randomly select 10 augmented images
selected_augmented_images = random.sample(augmented_images, 5)

# Display the selected augmented and corresponding original images
plt.figure(figsize=(10, 4))

for i, augmented_image_path in enumerate(selected_augmented_images):
    augmented_image = tf.keras.preprocessing.image.load_img(augmented_image_path)
    augmented_image = tf.keras.preprocessing.image.img_to_array(augmented_image)

    plt.subplot(2, 5, i + 1)
    plt.imshow(augmented_image.astype('uint8'))
    plt.title('Augmented {}'.format(i + 1))
    plt.axis('off')

    # Find the corresponding original image
    corresponding_original_image = augmented_image_path.replace('_aug', '')

    if corresponding_original_image in original_images:
        original_image = tf.keras.preprocessing.image.load_img(corresponding_original_image)
        original_image = tf.keras.preprocessing.image.img_to_array(original_image)

        plt.subplot(2, 5, i + 6)  # Place the original image next to the augmented image
        plt.imshow(original_image.astype('uint8'))
        plt.title('Original {}'.format(i + 1))
        plt.axis('off')

plt.tight_layout()
plt.show()

# %%
#get number of instances in folders in folder
def get_num_instances(folder):
  num_instances = [len(os.listdir(folder + '/' + i)) for i in os.listdir(folder)]
#return the number of instances
  return num_instances

# %% [markdown]
# ## Build Model

# %%
#create imagegenerator and load images, taking some images to create validation and training dataset
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

#create training dataset
train_generator = image_generator.flow_from_directory(
    '/content/MachineLearning/Dataset/train_set_augmented_random',
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical') 

#create validation dataset
validation_generator = image_generator.flow_from_directory(
    '/content/MachineLearning/Dataset/valid_set', 
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical') 

#create test dataset
test_generator = tf.keras.utils.image_dataset_from_directory(
    '/content/MachineLearning/Dataset/test_set',
    image_size=(64, 64),
    batch_size=32,
    labels='inferred',
    label_mode='categorical')

test_generator = test_generator.map(lambda x, y: (x / 255.0, y))
# Out:
# Found 46430 images belonging to 32 classes.
# Found 7715 images belonging to 32 classes.
# Found 7715 files belonging to 32 classes.

# %% [markdown]
# ### Simple CNN

# %%
#define simple CNN the model
model_simple = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(64, 64, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(32, activation='softmax')
])

# compile the model
model_simple.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

early_stop = EarlyStopping(patience=2, monitor='val_loss', mode='min', verbose=1)

# %%
# Start the timer
start_time = time.perf_counter()
# Get initial CPU times
initial_cpu_times = psutil.cpu_times()
# Get the current process ID
process_id = psutil.Process().pid

# train the model
history = model_simple.fit_generator(
    train_generator,
    steps_per_epoch=200,
    epochs=500,
    validation_data=validation_generator,
    validation_steps=100, 
    callbacks=[early_stop])

# Stop the timer
end_time = time.perf_counter()
# Get final CPU times
final_cpu_times = psutil.cpu_times()
# Get the memory usage of the current process
memory_info = psutil.Process(process_id).memory_info()
# Out:
# Epoch 1/500
# <ipython-input-88-88d9989888f4>:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model_simple.fit_generator(
# 200/200 [==============================] - 20s 93ms/step - loss: 3.2468 - accuracy: 0.0919 - val_loss: 2.5957 - val_accuracy: 0.3041
# Epoch 2/500
# 200/200 [==============================] - 21s 107ms/step - loss: 2.1751 - accuracy: 0.3665 - val_loss: 1.5533 - val_accuracy: 0.6159
# Epoch 3/500
# 200/200 [==============================] - 18s 92ms/step - loss: 1.4409 - accuracy: 0.5773 - val_loss: 1.0682 - val_accuracy: 0.7603
# Epoch 4/500
# 200/200 [==============================] - 19s 95ms/step - loss: 1.0862 - accuracy: 0.6743 - val_loss: 0.8154 - val_accuracy: 0.8306
# Epoch 5/500
# 200/200 [==============================] - 18s 92ms/step - loss: 0.9317 - accuracy: 0.7284 - val_loss: 0.6512 - val_accuracy: 0.8753
# Epoch 6/500
# 200/200 [==============================] - 19s 93ms/step - loss: 0.7796 - accuracy: 0.7633 - val_loss: 0.5594 - val_accuracy: 0.8813
# Epoch 7/500
# 200/200 [==============================] - 19s 93ms/step - loss: 0.7060 - accuracy: 0.7934 - val_loss: 0.4616 - val_accuracy: 0.8931
# Epoch 8/500
# 200/200 [==============================] - 19s 94ms/step - loss: 0.6612 - accuracy: 0.8034 - val_loss: 0.3847 - val_accuracy: 0.9178
# Epoch 9/500
# 200/200 [==============================] - 18s 92ms/step - loss: 0.5897 - accuracy: 0.8184 - val_loss: 0.3995 - val_accuracy: 0.9162
# Epoch 10/500
# 200/200 [==============================] - 19s 93ms/step - loss: 0.5431 - accuracy: 0.8379 - val_loss: 0.3180 - val_accuracy: 0.9303
# Epoch 11/500
# 200/200 [==============================] - 18s 91ms/step - loss: 0.5357 - accuracy: 0.8358 - val_loss: 0.3136 - val_accuracy: 0.9291
# Epoch 12/500
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4801 - accuracy: 0.8673 - val_loss: 0.2736 - val_accuracy: 0.9403
# Epoch 13/500
# 200/200 [==============================] - 19s 95ms/step - loss: 0.4769 - accuracy: 0.8598 - val_loss: 0.2933 - val_accuracy: 0.9397
# Epoch 14/500
# 200/200 [==============================] - 18s 92ms/step - loss: 0.4344 - accuracy: 0.8720 - val_loss: 0.2891 - val_accuracy: 0.9453
# Epoch 14: early stopping

# %%
# Calculate running time
running_time_simple = (end_time - start_time) / 60

# Calculate CPU usage
cpu_user_time = final_cpu_times.user - initial_cpu_times.user
cpu_system_time = final_cpu_times.system - initial_cpu_times.system
cpu_idle_time = final_cpu_times.idle - initial_cpu_times.idle

total_cpu_time = cpu_user_time + cpu_system_time + cpu_idle_time
cpu_usage_simple = (cpu_user_time + cpu_system_time) / total_cpu_time

# Calculate the absolute memory usage in bytes
absolute_memory_usage_simple = memory_info.rss

# Convert the memory usage to a human-readable format
memory_usage_human_simple = psutil._common.bytes2human(absolute_memory_usage_simple)

# Print the results
print("Running Time: {:.2f} minutes".format(running_time_simple))
print("CPU Usage: {:.2f} seconds".format(cpu_usage_simple))
print("Absolute Memory Usage: {} ({} bytes)".format(memory_usage_human_simple, absolute_memory_usage_simple))
# Out:
# Running Time: 5.01 minutes
# CPU Usage: 0.78 seconds
# Absolute Memory Usage: 2.5G (2669604864 bytes)

# %%
# Prepare the data
acc_s = history.history['accuracy']
val_acc_s = history.history['val_accuracy']
loss_s = history.history['loss']
val_loss_s = history.history['val_loss']
epochs = range(len(acc_s))

# Define the colors
colors = ['#a1c9f4', '#ffb6c1']  # Hexadecimal color codes for baby blue and baby green, respectively

# Plot accuracy
plt.figure()
plt.plot(epochs, acc_s, color=colors[0], label='Training accuracy')
plt.plot(epochs, val_acc_s, color=colors[1], label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

# Plot loss
plt.figure()
plt.plot(epochs, loss_s, color=colors[0], label='Training loss')
plt.plot(epochs, val_loss_s, color=colors[1], label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model_simple.evaluate(test_generator)

print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)
# Out:
# 242/242 [==============================] - 6s 23ms/step - loss: 0.2719 - accuracy: 0.9478
# Test loss: 0.27186962962150574
# Test accuracy: 0.9477640986442566

# %%
#for printing classification report, store labels and images in lists
labels = []
images = []
#extract images and labels from all batches in test set
for image_batch, label_batch in tqdm(test_generator):
    images.append(image_batch)
    labels.append(label_batch)
# Out:
# 100%|██████████| 242/242 [00:00<00:00, 266.85it/s]

# %%
#concatenate all images and labels
images = np.concatenate(images)
labels = np.concatenate(labels)

#predict labels for test set
y_pred_model = model_simple.predict(images)

#convert labels to integers
y_pred_m = np.argmax(y_pred_model, axis=1)
y_true = np.argmax(labels, axis=1)

#calculate classification report
report_s = classification_report(y_true, y_pred_m)

#calculate confusion matrix
cm_s = confusion_matrix(y_true, y_pred_m)

#plot classification report
print(report_s)

# Print the confusion matrix
print(cm_s)

#plot confusion matrix
plt.figure(figsize=(10,10))
sns.heatmap(cm_s, annot=True, fmt="d")
plt.show()

# Extract precision, recall, and f1-score from the classification report
lines = report_s.split('\n')
data = lines[-2].split()
precision_s = float(data[2])
recall_s = float(data[3])
f1_score_s = float(data[4])
# Out:
# 242/242 [==============================] - 5s 19ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       354
#            1       0.99      0.95      0.97       179
#            2       0.93      0.92      0.93       203
#            3       0.93      0.97      0.95       262
#            4       0.96      0.93      0.94       261
#            5       0.98      0.97      0.97       259
#            6       0.96      0.94      0.95       227
#            7       0.87      0.90      0.89       292
#            8       0.88      0.89      0.89       259
#            9       0.98      0.96      0.97       312
#           10       0.95      0.92      0.93       254
#           11       0.87      0.95      0.90       238
#           12       0.90      0.95      0.93       221
#           13       0.95      0.94      0.95       205
#           14       0.94      0.91      0.92       249
#           15       0.96      0.97      0.97       235
#           16       0.97      0.97      0.97       265
#           17       0.95      0.96      0.95       255
#           18       0.95      0.97      0.96       268
#           19       0.95      0.95      0.95       264
#           20       0.92      0.92      0.92       254
#           21       0.94      0.93      0.93       151
#           22       0.98      0.96      0.97       179
#           23       0.96      0.97      0.96       290
#           24       0.97      0.94      0.95       232
#           25       0.93      0.96      0.94       221
#           26       1.00      0.94      0.97       235
#           27       0.97      0.98      0.97       256
#           28       0.93      0.95      0.94       157
#           29       0.98      0.97      0.97       245
#           30       0.98      1.00      0.99       212
#           31       0.96      0.92      0.94       221
#
#     accuracy                           0.95      7715
#    macro avg       0.95      0.95      0.95      7715
# weighted avg       0.95      0.95      0.95      7715
#
# [[348   0   0 ...   0   0   0]
#  [  0 170   0 ...   0   0   0]
#  [  0   0 186 ...   0   0   0]
#  ...
#  [  0   0   0 ... 238   1   0]
#  [  0   0   0 ...   0 211   0]
#  [  0   0   0 ...   0   0 204]]

# %%
# Find misclassified samples
misclassified_indices = np.where(y_true != y_pred_m)[0]

# Get the most common misclassified class
most_common_misclass = np.argmax(np.bincount(y_true[misclassified_indices]))

# Get the indices of misclassified samples for the most common class
misclassified_indices_class = misclassified_indices[y_true[misclassified_indices] == most_common_misclass]

# Plot a selection of the misclassified images
num_samples_to_plot = 5
fig, axes = plt.subplots(1, num_samples_to_plot, figsize=(10, 4))

for i, index in enumerate(misclassified_indices_class[:num_samples_to_plot]):
    image = images[index]
    true_label = y_true[index]
    predicted_label = y_pred_m[index]
    
    axes[i].imshow(image)
    axes[i].set_title(f"True: {true_label}, Predicted: {predicted_label}")
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
# Plot a selection of the misclassified images
num_samples_to_plot = 5
fig, axes = plt.subplots(5, 2, figsize=(10, 6))

for i, index in enumerate(misclassified_indices_class[:num_samples_to_plot]):
    true_image = images[index]
    true_label = y_true[index]
    predicted_label = y_pred_m[index]

    # Plot the true image
    axes[i, 0].imshow(true_image)
    axes[i, 0].set_title(f"True: {true_label}")
    axes[i, 0].axis('off')

    # Find the first predicted image of the same class
    predicted_indices_class = np.where(y_pred_m == predicted_label)[0]
    predicted_image_index = next((idx for idx in predicted_indices_class if idx not in misclassified_indices), None)

    if predicted_image_index is not None:
        predicted_image = images[predicted_image_index]

        # Plot the predicted image
        axes[i, 1].imshow(predicted_image)
        axes[i, 1].set_title(f"Predicted: {predicted_label}")
        axes[i, 1].axis('off')

plt.tight_layout()
plt.show()

# %%
# Assuming y_pred_m contains the predicted labels and y_true contains the ground truth labels

num_wrong_labels = 0
number_predictions = len(y_pred_m)

for pred_label, true_label in zip(y_pred_m, y_true):
    if pred_label != true_label:
        num_wrong_labels += 1

print("Number of wrong predicted labels:", num_wrong_labels, "out of", number_predictions)
# Out:
# Number of wrong predicted labels: 403 out of 7715

# %% [markdown]
# ### Complex CNN

# %%
model_complex = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), input_shape=(64, 64, 3)),
    LeakyReLU(alpha=0.1),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv2D(32, (3,3)),
    LeakyReLU(alpha=0.1),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3)),
    LeakyReLU(alpha=0.1),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3)),
    LeakyReLU(alpha=0.1),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512),
    LeakyReLU(alpha=0.1),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(32, activation='softmax')
])

# Define a function that returns the learning rate as a function of the epoch number
def lr_schedule(epoch):
    lr = 0.001
    if epoch > 10:
        lr *= 0.5
    if epoch > 20:
        lr *= 0.5
    return lr

# Create the Adam optimizer and the learning rate scheduler
adam = Adam(learning_rate=0.001)
lr_scheduler = LearningRateScheduler(lr_schedule)

# compile the model
model_complex.compile(optimizer=adam,
                loss='categorical_crossentropy',
                metrics=['accuracy'])

early_stop = EarlyStopping(patience=5, monitor='val_loss', mode='min', verbose=1)

# %%
# Start the timer
start_time = time.perf_counter()
# Get initial CPU times
initial_cpu_times = psutil.cpu_times()
# Get the current process ID
process_id = psutil.Process().pid

# train the model
history_complex = model_complex.fit_generator(
    train_generator,
    steps_per_epoch=200,
    epochs=500,
    validation_data=validation_generator,
    validation_steps=100,
    callbacks=[early_stop, lr_scheduler])

# Stop the timer
end_time = time.perf_counter()
# Get final CPU times
final_cpu_times = psutil.cpu_times()
# Get the memory usage of the current process
memory_info = psutil.Process(process_id).memory_info()
# Out:
# Epoch 1/500
# <ipython-input-98-4e7bd692f73d>:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_complex = model_complex.fit_generator(
# 200/200 [==============================] - 28s 128ms/step - loss: 2.7111 - accuracy: 0.2619 - val_loss: 5.4407 - val_accuracy: 0.0772 - lr: 0.0010
# Epoch 2/500
# 200/200 [==============================] - 24s 119ms/step - loss: 1.6453 - accuracy: 0.4958 - val_loss: 2.8554 - val_accuracy: 0.2278 - lr: 0.0010
# Epoch 3/500
# 200/200 [==============================] - 24s 119ms/step - loss: 1.2833 - accuracy: 0.6034 - val_loss: 4.2673 - val_accuracy: 0.2269 - lr: 0.0010
# Epoch 4/500
# 200/200 [==============================] - 24s 120ms/step - loss: 1.0706 - accuracy: 0.6648 - val_loss: 1.8891 - val_accuracy: 0.4866 - lr: 0.0010
# Epoch 5/500
# 200/200 [==============================] - 24s 121ms/step - loss: 0.9486 - accuracy: 0.7033 - val_loss: 1.1389 - val_accuracy: 0.6550 - lr: 0.0010
# Epoch 6/500
# 200/200 [==============================] - 27s 134ms/step - loss: 0.8322 - accuracy: 0.7478 - val_loss: 1.3883 - val_accuracy: 0.5747 - lr: 0.0010
# Epoch 7/500
# 200/200 [==============================] - 24s 122ms/step - loss: 0.7627 - accuracy: 0.7602 - val_loss: 1.0213 - val_accuracy: 0.7041 - lr: 0.0010
# Epoch 8/500
# 200/200 [==============================] - 24s 122ms/step - loss: 0.7207 - accuracy: 0.7728 - val_loss: 0.8753 - val_accuracy: 0.7266 - lr: 0.0010
# Epoch 9/500
# 200/200 [==============================] - 24s 121ms/step - loss: 0.6772 - accuracy: 0.7819 - val_loss: 0.5496 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 10/500
# 200/200 [==============================] - 24s 120ms/step - loss: 0.6388 - accuracy: 0.8008 - val_loss: 1.7254 - val_accuracy: 0.5878 - lr: 0.0010
# Epoch 11/500
# 200/200 [==============================] - 24s 119ms/step - loss: 0.5790 - accuracy: 0.8188 - val_loss: 0.8419 - val_accuracy: 0.7631 - lr: 0.0010
# Epoch 12/500
# 200/200 [==============================] - 24s 122ms/step - loss: 0.4938 - accuracy: 0.8450 - val_loss: 0.3320 - val_accuracy: 0.9047 - lr: 5.0000e-04
# Epoch 13/500
# 200/200 [==============================] - 24s 122ms/step - loss: 0.4547 - accuracy: 0.8622 - val_loss: 0.3134 - val_accuracy: 0.9050 - lr: 5.0000e-04
# Epoch 14/500
# 200/200 [==============================] - 24s 121ms/step - loss: 0.4205 - accuracy: 0.8689 - val_loss: 0.4092 - val_accuracy: 0.8872 - lr: 5.0000e-04
# Epoch 15/500
# 200/200 [==============================] - 24s 121ms/step - loss: 0.4304 - accuracy: 0.8634 - val_loss: 0.6457 - val_accuracy: 0.8234 - lr: 5.0000e-04
# Epoch 16/500
# 200/200 [==============================] - 24s 122ms/step - loss: 0.4156 - accuracy: 0.8730 - val_loss: 0.8678 - val_accuracy: 0.7928 - lr: 5.0000e-04
# Epoch 17/500
# 200/200 [==============================] - 27s 133ms/step - loss: 0.3879 - accuracy: 0.8777 - val_loss: 0.8163 - val_accuracy: 0.7944 - lr: 5.0000e-04
# Epoch 18/500
# 200/200 [==============================] - 24s 122ms/step - loss: 0.3999 - accuracy: 0.8719 - val_loss: 0.3870 - val_accuracy: 0.8888 - lr: 5.0000e-04
# Epoch 18: early stopping

# %%
# Calculate running time
running_time_complex = (end_time - start_time) / 60

# Calculate CPU usage
cpu_user_time = final_cpu_times.user - initial_cpu_times.user
cpu_system_time = final_cpu_times.system - initial_cpu_times.system
cpu_idle_time = final_cpu_times.idle - initial_cpu_times.idle

total_cpu_time = cpu_user_time + cpu_system_time + cpu_idle_time
cpu_usage_complex = (cpu_user_time + cpu_system_time) / total_cpu_time

# Calculate the absolute memory usage in bytes
absolute_memory_usage_complex = memory_info.rss

# Convert the memory usage to a human-readable format
memory_usage_human_complex = psutil._common.bytes2human(absolute_memory_usage_complex)

# Print the results
print("Running Time: {:.2f} minutes".format(running_time_complex))
print("CPU Usage: {:.2f} seconds".format(cpu_usage_complex))
print("Absolute Memory Usage: {} ({} bytes)".format(memory_usage_human_complex, absolute_memory_usage_complex))
# Out:
# Running Time: 11.25 minutes
# CPU Usage: 0.57 seconds
# Absolute Memory Usage: 2.9G (3085463552 bytes)

# %%
# Prepare the data
acc_c = history_complex.history['accuracy']
val_acc_c = history_complex.history['val_accuracy']
loss_c = history_complex.history['loss']
val_loss_c = history_complex.history['val_loss']
epochs = range(len(acc_c))

# Define the colors
colors = ['#a1c9f4', '#ffb6c1']  # Hexadecimal color codes for baby blue and baby pink, respectively

# Plot accuracy
plt.plot(epochs, acc_c, color=colors[0], label='Training accuracy')
plt.plot(epochs, val_acc_c, color=colors[1], label='Validation accuracy')

plt.title('Training and validation accuracy of Complex CNN')
plt.legend(loc=0)
plt.figure()

# Plot loss
plt.figure()
plt.plot(epochs, loss_c, color=colors[0], label='Training loss')
plt.plot(epochs, val_loss_c, color=colors[1], label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model_complex.evaluate(test_generator)

print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)
# Out:
# 242/242 [==============================] - 6s 26ms/step - loss: 0.3808 - accuracy: 0.8848
# Test loss: 0.3807755708694458
# Test accuracy: 0.8847699165344238

# %%
#predict labels for test set
y_pred_model_complex = model_complex.predict(images)

#convert labels to integers
y_pred_m_complex = np.argmax(y_pred_model_complex, axis=1)
y_true_complex = np.argmax(labels, axis=1)

#calculate classification report
report_c = classification_report(y_true_complex, y_pred_m_complex)

#calculate confusion matrix
cm_c = confusion_matrix(y_true_complex, y_pred_m_complex)

#plot classification report
print(report_c)

# Print the confusion matrix
print(cm_c)

#plot confusion matrix
plt.figure(figsize=(10,10))
sns.heatmap(cm_c, annot=True, fmt="d")
plt.show()

# Extract precision, recall, and f1-score from the classification report
lines = report_s.split('\n')
data = lines[-2].split()
precision_c = float(data[2])
recall_c  = float(data[3])
f1_score_c = float(data[4])
# Out:
# 242/242 [==============================] - 7s 27ms/step
#               precision    recall  f1-score   support
#
#            0       0.69      1.00      0.82       354
#            1       1.00      0.91      0.95       179
#            2       0.90      0.94      0.92       203
#            3       0.81      0.94      0.87       262
#            4       0.90      0.93      0.92       261
#            5       1.00      0.81      0.89       259
#            6       0.81      0.95      0.88       227
#            7       0.70      0.96      0.81       292
#            8       0.87      0.60      0.71       259
#            9       0.87      0.85      0.86       312
#           10       0.90      0.91      0.90       254
#           11       0.78      0.88      0.83       238
#           12       0.98      0.88      0.93       221
#           13       0.98      0.91      0.94       205
#           14       0.98      0.63      0.77       249
#           15       1.00      0.68      0.81       235
#           16       0.97      0.87      0.92       265
#           17       0.81      0.95      0.87       255
#           18       0.96      0.90      0.93       268
#           19       0.97      0.87      0.92       264
#           20       0.79      0.93      0.85       254
#           21       0.83      1.00      0.91       151
#           22       1.00      0.87      0.93       179
#           23       0.89      0.94      0.92       290
#           24       0.97      0.84      0.90       232
#           25       0.97      0.91      0.94       221
#           26       0.95      0.97      0.96       235
#           27       0.93      0.95      0.94       256
#           28       0.94      0.87      0.90       157
#           29       0.94      0.91      0.93       245
#           30       1.00      0.81      0.90       212
#           31       0.88      0.95      0.91       221
#
#     accuracy                           0.88      7715
#    macro avg       0.91      0.88      0.89      7715
# weighted avg       0.90      0.88      0.88      7715
#
# [[354   0   0 ...   0   0   0]
#  [  0 162   0 ...   1   0   0]
#  [  4   0 190 ...   0   0   0]
#  ...
#  [  1   0   0 ... 224   0   0]
#  [ 10   0   0 ...   0 172   0]
#  [  1   0   0 ...   0   0 210]]

# %%
# Find misclassified samples
misclassified_indices = np.where(y_true_complex != y_pred_m_complex)[0]

# Get the most common misclassified class
most_common_misclass = np.argmax(np.bincount(y_true[misclassified_indices]))

# Get the indices of misclassified samples for the most common class
misclassified_indices_class = misclassified_indices[y_true_complex[misclassified_indices] == most_common_misclass]

# Plot a selection of the misclassified images
num_samples_to_plot = 5
fig, axes = plt.subplots(1, num_samples_to_plot, figsize=(15, 3))

for i, index in enumerate(misclassified_indices_class[:num_samples_to_plot]):
    image = images[index]
    true_label = y_true[index]
    predicted_label = y_pred_m_complex[index]
    
    axes[i].imshow(image)
    axes[i].set_title(f"True: {true_label}, Predicted: {predicted_label}")
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
# Plot a selection of the misclassified images
num_samples_to_plot = 5
fig, axes = plt.subplots(5, 2, figsize=(10, 6))

for i, index in enumerate(misclassified_indices_class[:num_samples_to_plot]):
    true_image = images[index]
    true_label = y_true_complex[index]
    predicted_label = y_pred_m_complex[index]

    # Plot the true image
    axes[i, 0].imshow(true_image)
    axes[i, 0].set_title(f"True: {true_label}")
    axes[i, 0].axis('off')

    # Find the first predicted image of the same class
    predicted_indices_class = np.where(y_pred_m_complex == predicted_label)[0]
    predicted_image_index = next((idx for idx in predicted_indices_class if idx not in misclassified_indices), None)

    if predicted_image_index is not None:
        predicted_image = images[predicted_image_index]

        # Plot the predicted image
        axes[i, 1].imshow(predicted_image)
        axes[i, 1].set_title(f"Predicted: {predicted_label}")
        axes[i, 1].axis('off')

plt.tight_layout()
plt.show()

# %%
# Assuming y_pred_m contains the predicted labels and y_true contains the ground truth labels

num_wrong_labels = 0
number_predictions = len(y_pred_m_complex)

for pred_label, true_label in zip(y_pred_m_complex, y_true_complex):
    if pred_label != true_label:
        num_wrong_labels += 1

print("Number of wrong predicted labels:", num_wrong_labels, "out of", number_predictions)
# Out:
# Number of wrong predicted labels: 889 out of 7715

# %% [markdown]
# ### GoogLeNet Inspired CNN

# %%
# Define the GoogLeNet-inspired CNN model
def googlenet(input_shape, num_classes):
    inputs = tf.keras.Input(shape=input_shape)

    # Stage 1
    x = layers.Conv2D(64, kernel_size=7, strides=2, padding='same', activation='relu')(inputs)
    x = layers.MaxPooling2D(pool_size=3, strides=2, padding='same')(x)
    x = layers.BatchNormalization()(x)

    # Stage 2
    x = layers.Conv2D(64, kernel_size=1, activation='relu')(x)
    x = layers.Conv2D(192, kernel_size=3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(pool_size=3, strides=2, padding='same')(x)

    # Stage 3 (Inception modules)
    # Inception module 1
    x = inception_module(x, 64, 96, 128, 16, 32, 32)
    # Inception module 2
    x = inception_module(x, 128, 128, 192, 32, 96, 64)

    # Add more inception modules as needed...

    # Final layers
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(1024, activation='relu')(x)
    x = layers.Dropout(0.4)(x)  # Optional: Add a dropout layer for regularization
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    # Create the model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    return model

# Helper function to create an inception module
def inception_module(x, filters_1x1, filters_3x3_reduce, filters_3x3, filters_5x5_reduce, filters_5x5, filters_pool_proj):
    conv_1x1 = layers.Conv2D(filters_1x1, kernel_size=1, activation='relu')(x)
    conv_3x3_reduce = layers.Conv2D(filters_3x3_reduce, kernel_size=1, activation='relu')(x)
    conv_3x3 = layers.Conv2D(filters_3x3, kernel_size=3, padding='same', activation='relu')(conv_3x3_reduce)
    conv_5x5_reduce = layers.Conv2D(filters_5x5_reduce, kernel_size=1, activation='relu')(x)
    conv_5x5 = layers.Conv2D(filters_5x5, kernel_size=5, padding='same', activation='relu')(conv_5x5_reduce)
    pool_proj = layers.Conv2D(filters_pool_proj, kernel_size=1, activation='relu')(x)

    output = layers.concatenate([conv_1x1, conv_3x3, conv_5x5, pool_proj], axis=-1)
    return output

# %%
# Define the input shape
input_shape = (64, 64, 3)
model_googlenet = googlenet(input_shape, 32)

#Compile the model
model_googlenet.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

early_stopping = EarlyStopping(patience=3, restore_best_weights=True)

# %%
# Start the timer
start_time = time.perf_counter()
# Get initial CPU times
initial_cpu_times = psutil.cpu_times()
# Get the current process ID
process_id = psutil.Process().pid


history_googlenet = model_googlenet.fit(
    train_generator,
    steps_per_epoch=train_generator.n // train_generator.batch_size,
    epochs=200,
    validation_data=validation_generator,
    validation_steps=validation_generator.n // validation_generator.batch_size,
    callbacks=[early_stopping]
)


# Stop the timer
end_time = time.perf_counter()
# Get final CPU times
final_cpu_times = psutil.cpu_times()
# Get the memory usage of the current process
memory_info = psutil.Process(process_id).memory_info()
# Out:
# Epoch 1/200
# 1450/1450 [==============================] - 338s 231ms/step - loss: 1.1650 - accuracy: 0.6351 - val_loss: 0.8858 - val_accuracy: 0.7230
# Epoch 2/200
# 1450/1450 [==============================] - 333s 230ms/step - loss: 0.3313 - accuracy: 0.8975 - val_loss: 0.3166 - val_accuracy: 0.9046
# Epoch 3/200
# 1450/1450 [==============================] - 329s 227ms/step - loss: 0.2164 - accuracy: 0.9330 - val_loss: 0.6143 - val_accuracy: 0.8199
# Epoch 4/200
# 1450/1450 [==============================] - 329s 227ms/step - loss: 0.1619 - accuracy: 0.9497 - val_loss: 24.6932 - val_accuracy: 0.1026
# Epoch 5/200
# 1450/1450 [==============================] - 335s 231ms/step - loss: 0.1327 - accuracy: 0.9586 - val_loss: 0.2227 - val_accuracy: 0.9409
# Epoch 6/200
# 1450/1450 [==============================] - 328s 226ms/step - loss: 0.1123 - accuracy: 0.9641 - val_loss: 15.5265 - val_accuracy: 0.2079
# Epoch 7/200
# 1450/1450 [==============================] - 329s 227ms/step - loss: 0.0975 - accuracy: 0.9688 - val_loss: 0.3088 - val_accuracy: 0.9077
# Epoch 8/200
# 1450/1450 [==============================] - 328s 226ms/step - loss: 0.0836 - accuracy: 0.9743 - val_loss: 0.1753 - val_accuracy: 0.9479
# Epoch 9/200
# 1450/1450 [==============================] - 328s 226ms/step - loss: 0.0771 - accuracy: 0.9766 - val_loss: 0.3372 - val_accuracy: 0.9004
# Epoch 10/200
# 1450/1450 [==============================] - 327s 226ms/step - loss: 0.0704 - accuracy: 0.9780 - val_loss: 0.1773 - val_accuracy: 0.9519
# Epoch 11/200
# 1450/1450 [==============================] - 326s 225ms/step - loss: 0.0645 - accuracy: 0.9805 - val_loss: 0.1196 - val_accuracy: 0.9694
# Epoch 12/200
# 1450/1450 [==============================] - 326s 225ms/step - loss: 0.0560 - accuracy: 0.9829 - val_loss: 0.1280 - val_accuracy: 0.9710
# Epoch 13/200
# 1450/1450 [==============================] - 325s 224ms/step - loss: 0.0568 - accuracy: 0.9830 - val_loss: 0.1097 - val_accuracy: 0.9764
# Epoch 14/200
# 1450/1450 [==============================] - 326s 225ms/step - loss: 0.0540 - accuracy: 0.9839 - val_loss: 0.1476 - val_accuracy: 0.9641
# Epoch 15/200
# 1450/1450 [==============================] - 325s 224ms/step - loss: 0.0471 - accuracy: 0.9861 - val_loss: 0.0996 - val_accuracy: 0.9785
# Epoch 16/200
# 1450/1450 [==============================] - 325s 224ms/step - loss: 0.0542 - accuracy: 0.9839 - val_loss: 0.1155 - val_accuracy: 0.9728
# Epoch 17/200
# 1450/1450 [==============================] - 325s 224ms/step - loss: 0.0472 - accuracy: 0.9863 - val_loss: 0.1222 - val_accuracy: 0.9763
# Epoch 18/200
# 1450/1450 [==============================] - 326s 225ms/step - loss: 0.0451 - accuracy: 0.9871 - val_loss: 0.1286 - val_accuracy: 0.9725

# %%
# Calculate running time
running_time_googlenet = (end_time - start_time) / 60

# Calculate CPU usage
cpu_user_time = final_cpu_times.user - initial_cpu_times.user
cpu_system_time = final_cpu_times.system - initial_cpu_times.system
cpu_idle_time = final_cpu_times.idle - initial_cpu_times.idle

total_cpu_time = cpu_user_time + cpu_system_time + cpu_idle_time
cpu_usage_googlenet = (cpu_user_time + cpu_system_time) / total_cpu_time

# Calculate the absolute memory usage in bytes
absolute_memory_usage_googlenet = memory_info.rss

# Convert the memory usage to a human-readable format
memory_usage_human_googlenet = psutil._common.bytes2human(absolute_memory_usage_googlenet)

# Print the results
print("Running Time: {:.2f} minutes".format(running_time_googlenet))
print("CPU Usage: {:.2f} seconds".format(cpu_usage_googlenet))
print("Absolute Memory Usage: {} ({} bytes)".format(memory_usage_human_googlenet, absolute_memory_usage_googlenet))
# Out:
# Running Time: 110.17 minutes
# CPU Usage: 0.83 seconds
# Absolute Memory Usage: 2.9G (3103903744 bytes)

# %%
# Prepare the data
acc_g = history_googlenet.history['accuracy']
val_acc_g = history_googlenet.history['val_accuracy']
loss_g = history_googlenet.history['loss']
val_loss_g = history_googlenet.history['val_loss']
epochs = range(len(acc_g))

# Define the colors
colors = ['#a1c9f4', '#ffb6c1']  # Hexadecimal color codes for blue and pink, respectively

# Plot accuracy
plt.plot(epochs, acc_g, color=colors[0], label='Training accuracy')
plt.plot(epochs, val_acc_g, color=colors[1], label='Validation accuracy')

plt.title('Training and validation accuracy of GoogLeNet Inspired CNN')
plt.legend(loc=0)
plt.figure()

# Plot loss
plt.figure()
plt.plot(epochs, loss_g, color=colors[0], label='Training loss')
plt.plot(epochs, val_loss_g, color=colors[1], label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()

plt.show()

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model_googlenet.evaluate(test_generator)

print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)
# Out:
# 242/242 [==============================] - 13s 54ms/step - loss: 0.1020 - accuracy: 0.9774
# Test loss: 0.10204558819532394
# Test accuracy: 0.9774465560913086

# %%
#predict labels for test set
y_pred_model= model_googlenet.predict(images)

#convert labels to integers
y_pred_m_googlenet = np.argmax(y_pred_model, axis=1)
y_true_googlenet = np.argmax(labels, axis=1)

#calculate classification report
report_g = classification_report(y_true_googlenet, y_pred_m_googlenet)

#calculate confusion matrix
cm_g = confusion_matrix(y_true_googlenet, y_pred_m_googlenet)

#plot classification report
print(report_g)

# Print the confusion matrix
print(cm_g)

#plot confusion matrix
plt.figure(figsize=(10,10))
sns.heatmap(cm_g, annot=True, fmt="d")
plt.show()

# Extract precision, recall, and f1-score from the classification report
lines = report_s.split('\n')
data = lines[-2].split()
precision_g = float(data[2])
recall_g = float(data[3])
f1_score_g = float(data[4])
# Out:
# 242/242 [==============================] - 13s 51ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       354
#            1       1.00      0.98      0.99       179
#            2       0.98      0.99      0.98       203
#            3       0.96      0.99      0.97       262
#            4       0.99      0.95      0.97       261
#            5       0.99      1.00      0.99       259
#            6       0.98      0.99      0.98       227
#            7       0.97      0.96      0.96       292
#            8       0.95      0.98      0.96       259
#            9       1.00      0.98      0.99       312
#           10       0.91      0.97      0.94       254
#           11       0.95      0.98      0.97       238
#           12       0.96      0.95      0.96       221
#           13       0.96      1.00      0.98       205
#           14       0.99      0.94      0.96       249
#           15       0.97      0.99      0.98       235
#           16       1.00      0.97      0.99       265
#           17       1.00      0.97      0.98       255
#           18       0.98      0.99      0.99       268
#           19       0.95      0.99      0.97       264
#           20       0.98      0.94      0.96       254
#           21       0.97      1.00      0.99       151
#           22       0.98      0.98      0.98       179
#           23       0.99      0.97      0.98       290
#           24       0.96      0.98      0.97       232
#           25       0.97      0.97      0.97       221
#           26       1.00      0.98      0.99       235
#           27       0.99      0.99      0.99       256
#           28       1.00      0.97      0.98       157
#           29       1.00      0.99      0.99       245
#           30       1.00      1.00      1.00       212
#           31       0.99      0.97      0.98       221
#
#     accuracy                           0.98      7715
#    macro avg       0.98      0.98      0.98      7715
# weighted avg       0.98      0.98      0.98      7715
#
# [[352   0   0 ...   0   0   0]
#  [  0 176   0 ...   0   0   0]
#  [  0   0 201 ...   0   0   0]
#  ...
#  [  0   0   0 ... 242   0   0]
#  [  0   0   0 ...   0 212   0]
#  [  0   0   0 ...   0   0 214]]

# %%
# Find misclassified samples
misclassified_indices = np.where(y_true_googlenet != y_pred_m_googlenet)[0]

# Get the most common misclassified class
most_common_misclass = np.argmax(np.bincount(y_true[misclassified_indices]))

# Get the indices of misclassified samples for the most common class
misclassified_indices_class = misclassified_indices[y_true_googlenet[misclassified_indices] == most_common_misclass]

# Plot a selection of the misclassified images
num_samples_to_plot = 5
fig, axes = plt.subplots(1, num_samples_to_plot, figsize=(15, 3))

for i, index in enumerate(misclassified_indices_class[:num_samples_to_plot]):
    image = images[index]
    true_label = y_true_googlenet[index]
    predicted_label = y_pred_m_googlenet[index]
    
    axes[i].imshow(image)
    axes[i].set_title(f"True: {true_label}, Predicted: {predicted_label}")
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
# Plot a selection of the misclassified images
num_samples_to_plot = 5
fig, axes = plt.subplots(5, 2, figsize=(10, 6))

for i, index in enumerate(misclassified_indices_class[:num_samples_to_plot]):
    true_image = images[index]
    true_label = y_true_googlenet[index]
    predicted_label = y_pred_m_googlenet[index]

    # Plot the true image
    axes[i, 0].imshow(true_image)
    axes[i, 0].set_title(f"True: {true_label}")
    axes[i, 0].axis('off')

    # Find the first predicted image of the same class
    predicted_indices_class = np.where(y_pred_m_googlenet == predicted_label)[0]
    predicted_image_index = next((idx for idx in predicted_indices_class if idx not in misclassified_indices), None)

    if predicted_image_index is not None:
        predicted_image = images[predicted_image_index]

        # Plot the predicted image
        axes[i, 1].imshow(predicted_image)
        axes[i, 1].set_title(f"Predicted: {predicted_label}")
        axes[i, 1].axis('off')

plt.tight_layout()
plt.show()

# %%
# Assuming y_pred_m_googlenet contains the predicted labels and y_true contains the ground truth labels

num_wrong_labels = 0
number_predictions = len(y_pred_m_googlenet)

for pred_label, true_label in zip(y_pred_m_googlenet, y_true_googlenet):
    if pred_label != true_label:
        num_wrong_labels += 1

print("Number of wrong predicted labels:", num_wrong_labels, "out of", number_predictions)

# %% [markdown]
# ### Comparison metrics perfomance

# %%
# Prepare the data
labels = ['Accuracy Simple CNN', 'Accuracy Complex CNN', 'Accuracy GoogLeNet']
values = [acc_s, acc_c, acc_g]

# Define the colors
colors = ['#a1c9f4', '#ffb6c1', '#b7e4b4']  # Hexadecimal color codes for baby blue, baby pink, and baby green, respectively

# Create a bar plot
plt.bar(labels, values, color=colors)
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.title('Model Accuracy')

# Rotate the x-axis labels
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
# Set the models and measures
models = ['Simple CNN', 'Complex CNN', 'GoogLeNet']
measures = ['Precision', 'Recall', 'F1-score']

# Values for each measure and model
precision_values = [precision_s, precision_c, precision_g]
recall_values = [recall_s, recall_c, recall_g]
f1_score_values = [f1_score_s, f1_score_c, f1_score_g]

# Define the colors
colors = ['#a1c9f4', '#ffb6c1', '#b7e4b4']

# Set the width of the bars
bar_width = 0.2

# Set the positions of the bars on the x-axis
r1 = np.arange(len(models))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Plot the precision, recall, and F1-score
plt.bar(r1, precision_values, color=colors[0], width=bar_width, edgecolor='white', label='Precision')
plt.bar(r2, recall_values, color=colors[1], width=bar_width, edgecolor='white', label='Recall')
plt.bar(r3, f1_score_values, color=colors[2], width=bar_width, edgecolor='white', label='F1-score')

# Add xticks and labels
plt.xticks([r + bar_width for r in range(len(models))], models)
plt.xlabel('Models')
plt.ylabel('Scores')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
# Create subplots
fig, axs = plt.subplots(3, 1, figsize=(8, 12))

# Plot Precision
axs[0].bar(models, precision_values, color=colors[0])
axs[0].set_title('Precision')

# Plot Recall
axs[1].bar(models, recall_values, color=colors[1])
axs[1].set_title('Recall')

# Plot F1-score
axs[2].bar(models, f1_score_values, color=colors[2])
axs[2].set_title('F1-score')

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### Comparison computational metrics

# %%
# Prepare the data
labels = ['Memory Usage Simple CNN', 'Memory Usage Complex CNN', 'Memory Usage GoogLeNet']
values = [absolute_memory_usage_simple, absolute_memory_usage_complex,absolute_memory_usage_googlenet]

# Define the colors
colors = ['#a1c9f4', '#ffb6c1', '#b7e4b4']  # Hexadecimal color codes for baby blue, baby pink, and baby green, respectively

# Create a bar plot
plt.bar(labels, values, color=colors)
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.title('Memory Usage Models')

# Rotate the x-axis labels
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
# Prepare the data
labels = ['CPU Usage Simple CNN', 'CPU Usage Complex CNN', 'CPU Usage GoogLeNet']
values = [cpu_usage_simple, cpu_usage_complex, cpu_usage_googlenet]

# Define the colors
colors = ['#a1c9f4', '#ffb6c1', '#b7e4b4']  # Hexadecimal color codes for baby blue, baby pink, and baby green, respectively

# Create a bar plot
plt.bar(labels, values, color=colors)
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.title('CPU Usage Models')

# Rotate the x-axis labels
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
# Prepare the data
labels = ['Running Time Simple CNN', 'Running Time Complex CNN', 'Running Time GoogLeNet']
values = [running_time_simple, running_time_complex, running_time_googlenet]

# Define the colors
colors = ['#a1c9f4', '#ffb6c1', '#b7e4b4']  # Hexadecimal color codes for baby blue, baby pink, and baby green, respectively

# Create a bar plot
plt.bar(labels, values, color=colors)
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.title('Running Time Models')

# Rotate the x-axis labels
plt.xticks(rotation=45)

# Show the plot
plt.show()
